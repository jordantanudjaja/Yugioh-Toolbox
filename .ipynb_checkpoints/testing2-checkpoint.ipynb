# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os
import re
import unicodedata
import psutil
import time
import concurrent.futures

# %%
yugioh_booster_web_page = 'https://yugioh.fandom.com/wiki/Booster_Pack'

cutoff_booster_pack = 'Eternity Code' # Current cutoff that will change over time once new english booster packs come out 
                                      # or new banlist is updated
                                      # Date of update: 26 July 2020

# %%
# Function to scrape the specific yugioh web page that contains the urls of all the booster packs up to the current meta
# and returns them in a list format
def get_booster_urls(url, cutoff):
    yugioh_booster_source = requests.get(url)

    if yugioh_booster_source.status_code == 200:
        yugioh_booster_site_html = BeautifulSoup(yugioh_booster_source.text.encode('utf-8'), 'html')

    booster_pack_url_list = list()

    # Appending the urls to a list
    for table in yugioh_booster_site_html.find_all('table', attrs = {'class': "nowraplinks navbox-subgroup"}):
        for ul in table.find_all('ul'):
            for a in ul.find_all('a'):
                booster_pack_url_list.append('https://yugioh.fandom.com' + a['href'])
                if a['title'] == cutoff:
                    break
            if a['title'] == cutoff:
                break
        if a['title'] == cutoff:
            break

    return booster_pack_url_list

# %%
booster_pack_url_list = get_booster_urls(yugioh_booster_web_page, cutoff_booster_pack)
print(len(booster_pack_url_list))
booster_pack_url_list
# Out:
# 107
# ['https://yugioh.fandom.com/wiki/Vol.1',
#  'https://yugioh.fandom.com/wiki/Vol.2',
#  'https://yugioh.fandom.com/wiki/Vol.3',
#  'https://yugioh.fandom.com/wiki/Vol.4',
#  'https://yugioh.fandom.com/wiki/Vol.5',
#  'https://yugioh.fandom.com/wiki/Vol.6',
#  'https://yugioh.fandom.com/wiki/Vol.7',
#  'https://yugioh.fandom.com/wiki/Booster_1',
#  'https://yugioh.fandom.com/wiki/Booster_2',
#  'https://yugioh.fandom.com/wiki/Booster_3',
#  'https://yugioh.fandom.com/wiki/Booster_4',
#  'https://yugioh.fandom.com/wiki/Booster_5',
#  'https://yugioh.fandom.com/wiki/Booster_6',
#  'https://yugioh.fandom.com/wiki/Booster_7',
#  'https://yugioh.fandom.com/wiki/Magic_Ruler_(Japanese)',
#  'https://yugioh.fandom.com/wiki/Pharaoh%27s_Servant_(Japanese)',
#  'https://yugioh.fandom.com/wiki/Curse_of_Anubis_(set)',
#  'https://yugioh.fandom.com/wiki/Thousand_Eyes_Bible',
#  'https://yugioh.fandom.com/wiki/Spell_of_Mask',
#  'https://yugioh.fandom.com/wiki/Labyrinth_of_Nightmare_(Japanese)',
#  'https://yugioh.fandom.com/wiki/Struggle_of_Chaos',
#  'https://yugioh.fandom.com/wiki/Mythological_Age',
#  'https://yugioh.fandom.com/wiki/Pharaonic_Guardian_(Japanese)',
#  'https://yugioh.fandom.com/wiki/The_New_Ruler',
#  'https://yugioh.fandom.com/wiki/Advent_of_Union',
#  'https://yugioh.fandom.com/wiki/Champion_of_Black_Magic',
#  'https://yugioh.fandom.com/wiki/Power_of_the_Guardian',
#  'https://yugioh.fandom.com/wiki/Threat_of_the_Dark_Demon_World',
#  'https://yugioh.fandom.com/wiki/Controller_of_Chaos',
#  'https://yugioh.fandom.com/wiki/Invader_of_Darkness_(set)',
#  'https://yugioh.fandom.com/wiki/The_Sanctuary_in_the_Sky_(set)',
#  'https://yugioh.fandom.com/wiki/Pharaoh%27s_Inheritance',
#  'https://yugioh.fandom.com/wiki/Legend_of_Blue_Eyes_White_Dragon',
#  'https://yugioh.fandom.com/wiki/Metal_Raiders',
#  'https://yugioh.fandom.com/wiki/Spell_Ruler',
#  'https://yugioh.fandom.com/wiki/Pharaoh%27s_Servant',
#  'https://yugioh.fandom.com/wiki/Labyrinth_of_Nightmare',
#  'https://yugioh.fandom.com/wiki/Legacy_of_Darkness',
#  'https://yugioh.fandom.com/wiki/Pharaonic_Guardian',
#  'https://yugioh.fandom.com/wiki/Magician%27s_Force',
#  'https://yugioh.fandom.com/wiki/Dark_Crisis',
#  'https://yugioh.fandom.com/wiki/Invasion_of_Chaos',
#  'https://yugioh.fandom.com/wiki/Ancient_Sanctuary',
#  'https://yugioh.fandom.com/wiki/Soul_of_the_Duelist',
#  'https://yugioh.fandom.com/wiki/Rise_of_Destiny',
#  'https://yugioh.fandom.com/wiki/Flaming_Eternity',
#  'https://yugioh.fandom.com/wiki/The_Lost_Millennium',
#  'https://yugioh.fandom.com/wiki/Cybernetic_Revolution',
#  'https://yugioh.fandom.com/wiki/Elemental_Energy',
#  'https://yugioh.fandom.com/wiki/Shadow_of_Infinity',
#  'https://yugioh.fandom.com/wiki/Enemy_of_Justice',
#  'https://yugioh.fandom.com/wiki/Power_of_the_Duelist',
#  'https://yugioh.fandom.com/wiki/Cyberdark_Impact',
#  'https://yugioh.fandom.com/wiki/Strike_of_Neos',
#  'https://yugioh.fandom.com/wiki/Force_of_the_Breaker',
#  'https://yugioh.fandom.com/wiki/Tactical_Evolution',
#  'https://yugioh.fandom.com/wiki/Gladiator%27s_Assault',
#  'https://yugioh.fandom.com/wiki/Phantom_Darkness',
#  'https://yugioh.fandom.com/wiki/Light_of_Destruction',
#  'https://yugioh.fandom.com/wiki/The_Duelist_Genesis',
#  'https://yugioh.fandom.com/wiki/Crossroads_of_Chaos',
#  'https://yugioh.fandom.com/wiki/Crimson_Crisis',
#  'https://yugioh.fandom.com/wiki/Raging_Battle',
#  'https://yugioh.fandom.com/wiki/Ancient_Prophecy',
#  'https://yugioh.fandom.com/wiki/Stardust_Overdrive',
#  'https://yugioh.fandom.com/wiki/Absolute_Powerforce',
#  'https://yugioh.fandom.com/wiki/The_Shining_Darkness',
#  'https://yugioh.fandom.com/wiki/Duelist_Revolution',
#  'https://yugioh.fandom.com/wiki/Starstrike_Blast',
#  'https://yugioh.fandom.com/wiki/Storm_of_Ragnarok',
#  'https://yugioh.fandom.com/wiki/Extreme_Victory',
#  'https://yugioh.fandom.com/wiki/Generation_Force',
#  'https://yugioh.fandom.com/wiki/Photon_Shockwave',
#  'https://yugioh.fandom.com/wiki/Order_of_Chaos',
#  'https://yugioh.fandom.com/wiki/Galactic_Overlord',
#  'https://yugioh.fandom.com/wiki/Return_of_the_Duelist',
#  'https://yugioh.fandom.com/wiki/Abyss_Rising',
#  'https://yugioh.fandom.com/wiki/Cosmo_Blazer',
#  'https://yugioh.fandom.com/wiki/Lord_of_the_Tachyon_Galaxy',
#  'https://yugioh.fandom.com/wiki/Judgment_of_the_Light',
#  'https://yugioh.fandom.com/wiki/Shadow_Specters',
#  'https://yugioh.fandom.com/wiki/Legacy_of_the_Valiant',
#  'https://yugioh.fandom.com/wiki/Primal_Origin',
#  'https://yugioh.fandom.com/wiki/Duelist_Alliance',
#  'https://yugioh.fandom.com/wiki/The_New_Challengers',
#  'https://yugioh.fandom.com/wiki/Secrets_of_Eternity',
#  'https://yugioh.fandom.com/wiki/Crossed_Souls',
#  'https://yugioh.fandom.com/wiki/Clash_of_Rebellions',
#  'https://yugioh.fandom.com/wiki/Dimension_of_Chaos',
#  'https://yugioh.fandom.com/wiki/Breakers_of_Shadow',
#  'https://yugioh.fandom.com/wiki/Shining_Victories',
#  'https://yugioh.fandom.com/wiki/The_Dark_Illusion',
#  'https://yugioh.fandom.com/wiki/Invasion:_Vengeance',
#  'https://yugioh.fandom.com/wiki/Raging_Tempest',
#  'https://yugioh.fandom.com/wiki/Maximum_Crisis',
#  'https://yugioh.fandom.com/wiki/Code_of_the_Duelist',
#  'https://yugioh.fandom.com/wiki/Circuit_Break',
#  'https://yugioh.fandom.com/wiki/Extreme_Force',
#  'https://yugioh.fandom.com/wiki/Flames_of_Destruction',
#  'https://yugioh.fandom.com/wiki/Cybernetic_Horizon',
#  'https://yugioh.fandom.com/wiki/Soul_Fusion',
#  'https://yugioh.fandom.com/wiki/Savage_Strike',
#  'https://yugioh.fandom.com/wiki/Dark_Neostorm',
#  'https://yugioh.fandom.com/wiki/Rising_Rampage',
#  'https://yugioh.fandom.com/wiki/Chaos_Impact',
#  'https://yugioh.fandom.com/wiki/Ignition_Assault',
#  'https://yugioh.fandom.com/wiki/Eternity_Code']

# %%
all_other_packs_url = 'https://yugioh.fandom.com/wiki/Template:Packs'

# These are denied card pack URLs that have not been updated with the latest cards from Konami
# or they are typos and have no cards in them
denied_urls = ['https://yugioh.fandom.com/wiki/Phantom_Rage_%2B1_Bonus_Pack',
               'https://yugioh.fandom.com/wiki/Rise_of_the_Duelist_%2B1_Bonus_Pack',
               'https://yugioh.fandom.com/wiki/Blazing_Vortex_%2B1_Bonus_Pack',
               'https://yugioh.fandom.com/wiki/Maximum_Gold',
               'https://yugioh.fandom.com/wiki/EX_Value_The_Gold_Box_%2B_ABYR%26CBLZ',
               'https://yugioh.fandom.com/wiki/EX_Value_The_Gold_Box_%2B_GS2013',
               'https://yugioh.fandom.com/wiki/Legendary_Duelists:_Rage_of_Ra',
               'https://yugioh.fandom.com/wiki/World_Premiere_Pack_2020',
               'https://yugioh.fandom.com/wiki/Dragons_of_Legend:_The_Complete_Series',
               'https://yugioh.fandom.com/wiki/Deck_Build_Pack:_Genesis_Impactors']

# %%
# Function is used specifically for card packs that are not booster packs like duelist packs, event packs to get the urls
# of all these other card packs from the Original Template web page containing everything about card packs
def get_other_cardpacks_url(url, denied_urls):
    all_other_packs_source = requests.get(url)
    
    if all_other_packs_source.status_code == 200:
        all_other_packs_html = BeautifulSoup(all_other_packs_source.text.encode('utf-8'), 'html')
        
    card_packs_url_list = list()
    for li in all_other_packs_html.find('table', attrs = {'class': "navbox"}).find_all('li'):
        for a in li.find_all('a'):
            card_packs_url_list.append('https://yugioh.fandom.com' + a['href'])
    card_packs_url_list.pop(0)        
    card_packs_url_list = list(set(card_packs_url_list))
    
    card_packs_url_list = [link for link in card_packs_url_list if link not in denied_urls]
    
    return card_packs_url_list

# %%
other_card_packs_url_list = get_other_cardpacks_url(all_other_packs_url, denied_urls)

# %%
# Function to filter the true card pack URLs from the URLs that have no table of cards in them
# or just random hyperlinks in general
def card_pack_url_filter(url, index):
    try:
        pd.read_html(url, attrs = {'class': 'wikitable'})
    except ValueError: 
        return index

# %%
time1 = time.perf_counter()

if __name__ == '__main__':
    # Multi-Threading to speed up the webscraping and filtering the actual card pack URLs
    with concurrent.futures.ThreadPoolExecutor(max_workers = 5) as executor:
        popped_indexes_iterable = executor.map(card_pack_url_filter, other_card_packs_url_list, range(len(other_card_packs_url_list)))
    print(f'{time.perf_counter() - time1} seconds')
    popped_indexes = list(popped_indexes_iterable)
    popped_indexes = [i for i in popped_indexes if i != None]

for index in sorted(popped_indexes, reverse = True):
    del other_card_packs_url_list[index]

print(len(other_card_packs_url_list))
other_card_packs_url_list
# Out:
# 170.87979810000002 seconds
# 276
# ['https://yugioh.fandom.com/wiki/Premium_Pack_Vol.14_1st_Wave',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_17',
#  'https://yugioh.fandom.com/wiki/Destiny_Soldiers',
#  'https://yugioh.fandom.com/wiki/Star_Pack_2013',
#  'https://yugioh.fandom.com/wiki/Surpassing_10000_Cards_Commemoration_Special_Pack',
#  'https://yugioh.fandom.com/wiki/Legendary_Collection_4:_Joey%27s_World_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Speed_Duel:_Arena_of_Lost_Souls',
#  'https://yugioh.fandom.com/wiki/The_Infinity_Chasers',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_5',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2017',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_2015',
#  'https://yugioh.fandom.com/wiki/Legendary_Collection_Kaiba_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_10',
#  'https://yugioh.fandom.com/wiki/20th_Secret_Rare_Special_Pack',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_Volume_2',
#  'https://yugioh.fandom.com/wiki/20th_Secret_Rare_Challenge_Pack',
#  'https://yugioh.fandom.com/wiki/Legendary_Collection_3:_Yugi%27s_World_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Structure_Deck:_Revolver_Extra_Deck_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/Hidden_Arsenal_3',
#  'https://yugioh.fandom.com/wiki/Legendary_Duelists:_White_Dragon_Abyss',
#  'https://yugioh.fandom.com/wiki/Demo_Deck_2016',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Legend_Duelist_2',
#  'https://yugioh.fandom.com/wiki/Hidden_Arsenal_2',
#  'https://yugioh.fandom.com/wiki/Movie_Pack',
#  'https://yugioh.fandom.com/wiki/Millennium_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.11',
#  'https://yugioh.fandom.com/wiki/Fusion_Enforcers',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.5',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Duelists_of_Gloom',
#  'https://yugioh.fandom.com/wiki/Structure_Deck:_Soulburner_Extra_Deck_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_4:_Part_A',
#  'https://yugioh.fandom.com/wiki/Number_Hunters',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Yuma_2:_Gogogo_%26_Dododo',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.9',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2013_-_Promotion_Pack_B',
#  'https://yugioh.fandom.com/wiki/LINK_VRAINS_Pack_3',
#  'https://yugioh.fandom.com/wiki/Special_Pack_Vol.1',
#  'https://yugioh.fandom.com/wiki/The_Rarity_Collection',
#  'https://yugioh.fandom.com/wiki/Dragons_of_Legend_2',
#  'https://yugioh.fandom.com/wiki/Extra_Pack:_Knights_of_Order',
#  'https://yugioh.fandom.com/wiki/20th_Anniversary_Legend_Collection',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2015_-_Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/Ra_Yellow_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Yusei',
#  'https://yugioh.fandom.com/wiki/Speed_Duel:_Attack_from_the_Deep',
#  'https://yugioh.fandom.com/wiki/Special_Pack_Vol.3',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_Volume_4',
#  'https://yugioh.fandom.com/wiki/Legendary_Duelists:_Magical_Hero',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_15',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.1',
#  'https://yugioh.fandom.com/wiki/Special_Pack_20th_Anniversary_Edition_Vol.3',
#  'https://yugioh.fandom.com/wiki/Special_Pack_20th_Anniversary_Edition_Vol.4',
#  'https://yugioh.fandom.com/wiki/Star_Pack_VRAINS',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Legend_Duelist_3',
#  'https://yugioh.fandom.com/wiki/Star_Pack_Battle_Royal',
#  'https://yugioh.fandom.com/wiki/World_Superstars',
#  'https://yugioh.fandom.com/wiki/Millennium_Pack_(OCG)',
#  'https://yugioh.fandom.com/wiki/Gold_Series_2011',
#  'https://yugioh.fandom.com/wiki/Yu-Gi-Oh!_3D_Bonds_Beyond_Time_Movie_Pack',
#  'https://yugioh.fandom.com/wiki/War_of_the_Giants_Reinforcements',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_2016',
#  'https://yugioh.fandom.com/wiki/Special_Pack_20th_Anniversary_Edition_Vol.6',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_4:_Part_B',
#  'https://yugioh.fandom.com/wiki/Dark_Ceremony_Edition',
#  'https://yugioh.fandom.com/wiki/Duelist_Saga',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2011_-_Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Zane_Truesdale',
#  'https://yugioh.fandom.com/wiki/Token_Pack_Version_2.0',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Kaiba',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_2_(TCG)',
#  'https://yugioh.fandom.com/wiki/Battles_of_Legend:_Light%27s_Revenge',
#  'https://yugioh.fandom.com/wiki/Hidden_Arsenal_4:_Trishula%27s_Triumph',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Yusei_3',
#  'https://yugioh.fandom.com/wiki/Booster_SP:_Fusion_Enforcers',
#  'https://yugioh.fandom.com/wiki/Starter_Deck_2013_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/Space-Time_Showdown_Power-Up_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Road_-Piece_of_Memory-_Side:_Yami_Yugi',
#  'https://yugioh.fandom.com/wiki/World_Championship_2011_Card_Pack',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2012_-_Promotion_Pack_A',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.4',
#  'https://yugioh.fandom.com/wiki/Deck_Build_Pack:_Mystic_Fighters',
#  'https://yugioh.fandom.com/wiki/Duel_Power',
#  'https://yugioh.fandom.com/wiki/Booster_SP:_Tribe_Force',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_2020',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Yuma',
#  'https://yugioh.fandom.com/wiki/Legendary_Duelists:_Season_1',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Kastle_Siblings',
#  'https://yugioh.fandom.com/wiki/Structure_Deck_R:_Dragunity_Drive_Deck_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/LINK_VRAINS_Pack_2',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Kite',
#  'https://yugioh.fandom.com/wiki/Collection_Pack:_Duelist_of_Revolution_Version',
#  'https://yugioh.fandom.com/wiki/Collectors_Pack:_Duelist_of_Legend_Version',
#  'https://yugioh.fandom.com/wiki/Battle_Pack_2:_War_of_the_Giants',
#  'https://yugioh.fandom.com/wiki/Legendary_Collection_5D%27s_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/The_Gold_Box',
#  'https://yugioh.fandom.com/wiki/Entry_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Road_-Piece_of_Memory-_Side:_Yugi_Muto',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_14',
#  'https://yugioh.fandom.com/wiki/Legendary_Collection_2:_The_Duel_Academy_Years_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Jump_Victory_Carnival_2016_-_Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.7',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_2019',
#  'https://yugioh.fandom.com/wiki/Rarity_Collection_Premium_Gold_Edition',
#  'https://yugioh.fandom.com/wiki/Wing_Raiders',
#  'https://yugioh.fandom.com/wiki/Pendulum_Evolution',
#  'https://yugioh.fandom.com/wiki/Gold_Series_2014',
#  'https://yugioh.fandom.com/wiki/Gold_Series_3',
#  'https://yugioh.fandom.com/wiki/Special_Pack',
#  'https://yugioh.fandom.com/wiki/Special_Pack_20th_Anniversary_Edition_Vol.1',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_3',
#  'https://yugioh.fandom.com/wiki/Star_Pack_ARC-V',
#  'https://yugioh.fandom.com/wiki/Star_Pack_2014',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_2017',
#  'https://yugioh.fandom.com/wiki/Legendary_Duelists',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2009_-_Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/Gold_Series_4:_Pyramids_Edition',
#  'https://yugioh.fandom.com/wiki/Super_Starter_Power-Up_Pack',
#  'https://yugioh.fandom.com/wiki/Deck_Custom_Pack_01',
#  'https://yugioh.fandom.com/wiki/Demo_Pack',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2012_Vol.1',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_13',
#  'https://yugioh.fandom.com/wiki/Gold_Series_2009',
#  'https://yugioh.fandom.com/wiki/Movie_Pack_Vol.2',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_(Japanese)',
#  'https://yugioh.fandom.com/wiki/Demo_Deck_2015',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2012_Vol.2',
#  'https://yugioh.fandom.com/wiki/Dark_Saviors',
#  'https://yugioh.fandom.com/wiki/Starter_Deck_2014_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_2019',
#  'https://yugioh.fandom.com/wiki/Exclusive_Pack',
#  'https://yugioh.fandom.com/wiki/Hidden_Arsenal',
#  'https://yugioh.fandom.com/wiki/20th_Anniversary_Pack_1st_Wave',
#  'https://yugioh.fandom.com/wiki/Gold_Series',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Yugi',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_16',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.12',
#  'https://yugioh.fandom.com/wiki/Collectors_Pack:_Duelist_of_Flash_Version',
#  'https://yugioh.fandom.com/wiki/Speed_Duel_Demo_Deck',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_9',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Aster_Phoenix',
#  'https://yugioh.fandom.com/wiki/20th_Secret_Rare_Final_Challenge_Pack',
#  'https://yugioh.fandom.com/wiki/Expansion_Pack_Vol.4',
#  'https://yugioh.fandom.com/wiki/Gold_Series_(OCG)',
#  'https://yugioh.fandom.com/wiki/Promotional_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Legend_Duelist_5',
#  'https://yugioh.fandom.com/wiki/Premium_Gold:_Infinite_Gold',
#  'https://yugioh.fandom.com/wiki/Expansion_Pack_Vol.1',
#  'https://yugioh.fandom.com/wiki/Collectors_Pack_2018',
#  'https://yugioh.fandom.com/wiki/Battles_of_Legend:_Hero%27s_Revenge',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Yusei_2',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.13',
#  'https://yugioh.fandom.com/wiki/2017_Mega-Tin_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/2018_Mega-Tin_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Legendary_Duelists:_Sisters_of_the_Rose',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Rivals_of_the_Pharaoh',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_2018',
#  'https://yugioh.fandom.com/wiki/Battles_of_Legend:_Armageddon',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Dimensional_Guardians',
#  'https://yugioh.fandom.com/wiki/Structure_Deck:_Sacred_Beasts_of_Chaos_Sacred_Beasts_Unleashed_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Jesse_Anderson',
#  'https://yugioh.fandom.com/wiki/Legendary_Duelists:_Immortal_Destiny',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Legend_Duelist_4',
#  'https://yugioh.fandom.com/wiki/Collectors_Pack:_Duelist_of_Destiny_Version',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2014_-_Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/Starter_Pack_Volume_3',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.6',
#  'https://yugioh.fandom.com/wiki/Deck_Build_Pack:_Dark_Savers',
#  'https://yugioh.fandom.com/wiki/Gold_Series_2012',
#  'https://yugioh.fandom.com/wiki/Hidden_Arsenal_7:_Knight_of_Stars',
#  'https://yugioh.fandom.com/wiki/Duelist_Set:_Version_Machine-Gear_Troopers_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Crow',
#  'https://yugioh.fandom.com/wiki/2015_Mega-Tin_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Special_Pack_20th_Anniversary_Edition_Vol.2',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Jaden_Yuki_3',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_Limited_Pack_2019',
#  'https://yugioh.fandom.com/wiki/Collectors_Pack_2017',
#  'https://yugioh.fandom.com/wiki/Special_Pack_Vol.4',
#  'https://yugioh.fandom.com/wiki/Noble_Knights_of_the_Round_Table_Power-Up_Pack',
#  'https://yugioh.fandom.com/wiki/War_of_the_Giants:_Round_2',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2012_-_Promotion_Pack_B',
#  'https://yugioh.fandom.com/wiki/Rarity_Collection_20th_Anniversary_Edition',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_19',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_(TCG)',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_6',
#  'https://yugioh.fandom.com/wiki/Gold_Series_2013',
#  'https://yugioh.fandom.com/wiki/Shadows_in_Valhalla',
#  'https://yugioh.fandom.com/wiki/Structure_Deck:_Rebirth_of_Shaddoll_Deck_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.2',
#  'https://yugioh.fandom.com/wiki/Booster_SP:_Destiny_Soldiers',
#  'https://yugioh.fandom.com/wiki/2016_Mega-Tin_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Starter_Pack_Volume_1',
#  'https://yugioh.fandom.com/wiki/Advanced_Demo_Deck_Extra_Pack',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_Limited_Pack_2020',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2013_Vol.4',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_20',
#  'https://yugioh.fandom.com/wiki/Token_Pack_(Japanese)',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2013_-_Promotion_Pack_A',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Jaden_Yuki_2',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_11',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Legend_Duelist',
#  'https://yugioh.fandom.com/wiki/Starter_Pack_Volume_2',
#  'https://yugioh.fandom.com/wiki/Spirit_Warriors',
#  'https://yugioh.fandom.com/wiki/Gold_Series_2010',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.8',
#  'https://yugioh.fandom.com/wiki/Dragons_of_Legend',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_12',
#  'https://yugioh.fandom.com/wiki/The_Secret_Forces',
#  'https://yugioh.fandom.com/wiki/High-Speed_Riders',
#  'https://yugioh.fandom.com/wiki/Gold_Series:_Haunted_Mine',
#  'https://yugioh.fandom.com/wiki/Collectors_Pack:_ZEXAL_Version',
#  'https://yugioh.fandom.com/wiki/Structure_Deck:_Masters_of_the_Spiritual_Arts_Spirit_Art_Awakening_Pack',
#  'https://yugioh.fandom.com/wiki/Booster_SP:_Highspeed_Riders',
#  'https://yugioh.fandom.com/wiki/20th_Anniversary_Pack_2nd_Wave',
#  'https://yugioh.fandom.com/wiki/Mystic_Fighters',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_18',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_2012',
#  'https://yugioh.fandom.com/wiki/Hidden_Arsenal_5:_Steelswarm_Invasion',
#  'https://yugioh.fandom.com/wiki/Deck_Build_Pack:_Spirit_Warriors',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2013_Vol.3',
#  'https://yugioh.fandom.com/wiki/Collection_Pack_2020',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_8',
#  'https://yugioh.fandom.com/wiki/World_Championship_2010_Card_Pack',
#  'https://yugioh.fandom.com/wiki/Fists_of_the_Gadgets',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_7',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Chazz_Princeton',
#  'https://yugioh.fandom.com/wiki/Expansion_Pack_Vol.2',
#  'https://yugioh.fandom.com/wiki/2019_Gold_Sarcophagus_Tin_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Jaden_Yuki',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2018',
#  'https://yugioh.fandom.com/wiki/Battle_Pack_3:_Monster_League',
#  'https://yugioh.fandom.com/wiki/Deck_Build_Pack:_Infinity_Chasers',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Pharaoh%27s_Memories',
#  'https://yugioh.fandom.com/wiki/Hidden_Arsenal_6:_Omega_Xyz',
#  'https://yugioh.fandom.com/wiki/Extra_Pack_Volume_3',
#  'https://yugioh.fandom.com/wiki/Duel_Overload',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.3',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_4',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.10',
#  'https://yugioh.fandom.com/wiki/Hidden_Summoners',
#  'https://yugioh.fandom.com/wiki/Deck_Build_Pack:_Hidden_Summoners',
#  'https://yugioh.fandom.com/wiki/Legendary_Duelists:_Ancient_Millennium',
#  'https://yugioh.fandom.com/wiki/Expansion_Pack_Vol.3',
#  'https://yugioh.fandom.com/wiki/Toon_Chaos',
#  'https://yugioh.fandom.com/wiki/Deck_Build_Pack:_Secret_Slayers',
#  'https://yugioh.fandom.com/wiki/Token_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_2_(Japanese)',
#  'https://yugioh.fandom.com/wiki/Booster_SP:_Raging_Masters',
#  'https://yugioh.fandom.com/wiki/Battles_of_Legend:_Relentless_Revenge',
#  'https://yugioh.fandom.com/wiki/Special_Pack_20th_Anniversary_Edition_Vol.5',
#  'https://yugioh.fandom.com/wiki/Dragons_of_Legend:_Unleashed',
#  'https://yugioh.fandom.com/wiki/Special_Pack_Vol.2',
#  'https://yugioh.fandom.com/wiki/Jump_Festa_2010_-_Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Gold',
#  'https://yugioh.fandom.com/wiki/Secret_Slayers',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Battle_City',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_3:_Part_A',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_2019',
#  'https://yugioh.fandom.com/wiki/LINK_VRAINS_Pack',
#  'https://yugioh.fandom.com/wiki/Premium_Gold:_Return_of_the_Bling',
#  'https://yugioh.fandom.com/wiki/Promotion_Pack_3:_Part_B',
#  'https://yugioh.fandom.com/wiki/Anniversary_Pack',
#  'https://yugioh.fandom.com/wiki/Duelist_Set:_Version_Lightlord_Judgment_Enhancement_Pack',
#  'https://yugioh.fandom.com/wiki/Booster_SP:_Wing_Raiders',
#  'https://yugioh.fandom.com/wiki/Premium_Pack_Vol.14_2nd_Wave',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Legend_Duelist_6',
#  'https://yugioh.fandom.com/wiki/Duelist_Pack:_Yugi_(OCG)',
#  'https://yugioh.fandom.com/wiki/Gold_Pack_2016',
#  'https://yugioh.fandom.com/wiki/Extra_Pack:_Sword_of_Knights',
#  'https://yugioh.fandom.com/wiki/Extra_Pack',
#  'https://yugioh.fandom.com/wiki/Token_Pack_Version_1.0',
#  'https://yugioh.fandom.com/wiki/Duelist_Festival_2016_-_Promotion_Pack',
#  'https://yugioh.fandom.com/wiki/2014_Mega-Tin_Mega_Pack',
#  'https://yugioh.fandom.com/wiki/Battle_Pack:_Epic_Dawn',
#  'https://yugioh.fandom.com/wiki/Yu-Gi-Oh!_The_Dark_Side_of_Dimensions_Movie_Pack']

# %%
all_card_packs_url_list = booster_pack_url_list + other_card_packs_url_list
len(all_card_packs_url_list)
# Out:
# 383

# %%
#booster_pack_url = 'https://yugioh.fandom.com/wiki/LINK_VRAINS_Duelist_Set#Japanese'
#booster_pack_url = 'https://yugioh.fandom.com/wiki/Legendary_Duelists:_Season_1'
#booster_pack_url = 'https://yugioh.fandom.com/wiki/Vol.1'
#booster_pack_url = 'https://yugioh.fandom.com/wiki/Secrets_of_Eternity'
#booster_pack_url = 'https://yugioh.fandom.com/wiki/Duelist_Pack:_Kite'
booster_pack_url = 'https://yugioh.fandom.com/wiki/Collection_Pack_2020'

# %%
# Function that scrapes the card pack URL and return all the urls of each card from the card
# pack in a list format
def get_card_urls(card_pack_url):
    card_pack_source = requests.get(card_pack_url)

    if card_pack_source.status_code == 200:
        card_pack_html = BeautifulSoup(card_pack_source.text.encode('utf-8'), 'html.parser')

    class_or_id = 'class'
    attribute_name = "wikitable"
    # Code hacks for 2 card pack URLs
    if card_pack_url == 'https://yugioh.fandom.com/wiki/Duelist_Pack:_Kite':
        attribute_name = "sortable"
    elif card_pack_url == 'https://yugioh.fandom.com/wiki/Collection_Pack_2020':
        class_or_id = 'id'
        attribute_name = 'Top_table'
        
    
    card_url_list = list()
    
    for card_table in card_pack_html.find_all('table', attrs = {class_or_id: attribute_name}):
        # Building a table of hyperlinks because pd.read_html does not read the hyperlinks, but only reads the unlinked
        # text of tables
        record = list()
        for tr in card_table.findAll("tr"):
            ths = tr.findAll("th")
            if ths != []:
                columns = [th.text.replace('\n', '').strip() for th in ths]
            else:
                row = list()
                for td in tr.find_all('td'):
                    try:
                        row.append(td.a['href'])
                    except KeyError:
                        row.append(td.a.text)
                    except TypeError:
                        row.append(td.text)
                record.append(row)

        card_pack_df = pd.DataFrame(data = record, columns = columns)
        try:
            card_pack_df.rename(columns = {'English name': 'Card Name'}, inplace = True)
            # Raise keyword is used because KeyError was handled previously above, thus raise is
            # needed to  reraise the KeyError if it comes up again
            raise KeyError() 
        except KeyError:
            card_pack_df.rename(columns = {'Name': 'Card Name'}, inplace = True)
        finally:
            card_pack_df['Card Name'] = card_pack_df['Card Name'].apply(lambda x: 'https://yugioh.fandom.com' + x)
            card_url_list.extend(list(card_pack_df['Card Name']))
           
    
    card_url_list = list(set(card_url_list))
    return card_url_list

# %%
get_card_urls(booster_pack_url)
# Out:
# ['https://yugioh.fandom.com/wiki/Fossil_Warrior_Skull_King',
#  'https://yugioh.fandom.com/wiki/Weathering_Soldier',
#  'https://yugioh.fandom.com/wiki/Super_All_In!',
#  'https://yugioh.fandom.com/wiki/Glacial_Beast_Polar_Penguin',
#  'https://yugioh.fandom.com/wiki/Glacial_Beast_Blizzard_Wolf',
#  'https://yugioh.fandom.com/wiki/Fire_Flint_Lady',
#  'https://yugioh.fandom.com/wiki/Fossil_Dragon_Skullgar',
#  'https://yugioh.fandom.com/wiki/Fossil_Warrior_Skull_Knight',
#  'https://yugioh.fandom.com/wiki/Appliancer_Reuse',
#  'https://yugioh.fandom.com/wiki/Number_C1:_Numeron_Chaos_Gate_Sunya',
#  'https://yugioh.fandom.com/wiki/Number_4:_Numeron_Gate_Catvari',
#  'https://yugioh.fandom.com/wiki/Appliancer_Socketroll',
#  'https://yugioh.fandom.com/wiki/High_Rate_Draw',
#  'https://yugioh.fandom.com/wiki/Number_2:_Numeron_Gate_Dve',
#  'https://yugioh.fandom.com/wiki/Numeron_Wall',
#  'https://yugioh.fandom.com/wiki/Appliancer_Celtopus',
#  'https://yugioh.fandom.com/wiki/Psychic_Wave',
#  'https://yugioh.fandom.com/wiki/Appliancer_Breakerbuncle',
#  'https://yugioh.fandom.com/wiki/Malefic_Paradigm_Dragon',
#  'https://yugioh.fandom.com/wiki/Number_1:_Numeron_Gate_Ekam',
#  'https://yugioh.fandom.com/wiki/Specimen_Inspection',
#  'https://yugioh.fandom.com/wiki/Appliancer_Laundry_Dragon',
#  'https://yugioh.fandom.com/wiki/Appliancer_Dryer_Drake',
#  'https://yugioh.fandom.com/wiki/Glacial_Beast_Iceberg_Narwhal',
#  'https://yugioh.fandom.com/wiki/Appliancer_Vacculephant',
#  'https://yugioh.fandom.com/wiki/Numeron_Network',
#  'https://yugioh.fandom.com/wiki/Flower_Cardian_Cherry_Blossom',
#  'https://yugioh.fandom.com/wiki/Afterglow',
#  'https://yugioh.fandom.com/wiki/Fossil_Warrior_Skull_Bone',
#  'https://yugioh.fandom.com/wiki/Time_Stream',
#  'https://yugioh.fandom.com/wiki/Appliancer_Kappa_Scale',
#  'https://yugioh.fandom.com/wiki/Number_39:_Utopia',
#  'https://yugioh.fandom.com/wiki/Number_3:_Numeron_Gate_Trini',
#  'https://yugioh.fandom.com/wiki/Armored_White_Bear',
#  'https://yugioh.fandom.com/wiki/Intruder_Alarm_-_Yellow_Alert',
#  'https://yugioh.fandom.com/wiki/Dark_Spell_Regeneration',
#  'https://yugioh.fandom.com/wiki/Appliancer_Electrilyrical_World',
#  'https://yugioh.fandom.com/wiki/Fossil_Fusion',
#  'https://yugioh.fandom.com/wiki/Numeron_Calling',
#  'https://yugioh.fandom.com/wiki/Penguin_Torpedo',
#  'https://yugioh.fandom.com/wiki/Number_3:_Cicada_King',
#  'https://yugioh.fandom.com/wiki/Fossil_Dragon_Skullgios',
#  'https://yugioh.fandom.com/wiki/Miracle_Rupture',
#  'https://yugioh.fandom.com/wiki/Appliancer_Test',
#  'https://yugioh.fandom.com/wiki/Appliancer_Copybokkle',
#  'https://yugioh.fandom.com/wiki/Powered_Crawler']

# %%
get_card_urls(booster_pack_url)
# Out:
# ['https://yugioh.fandom.com/wiki/Galaxy_Zero',
#  'https://yugioh.fandom.com/wiki/Twin_Photon_Lizard',
#  'https://yugioh.fandom.com/wiki/Number_20:_Giga-Brilliant',
#  'https://yugioh.fandom.com/wiki/Galaxy_Knight',
#  'https://yugioh.fandom.com/wiki/Photon_Circle',
#  'https://yugioh.fandom.com/wiki/Dimension_Wanderer',
#  'https://yugioh.fandom.com/wiki/Galaxy-Eyes_Photon_Dragon',
#  'https://yugioh.fandom.com/wiki/Photon_Pirate',
#  'https://yugioh.fandom.com/wiki/Photon_Thrasher',
#  'https://yugioh.fandom.com/wiki/Reverse_Buster',
#  'https://yugioh.fandom.com/wiki/Number_56:_Gold_Rat',
#  'https://yugioh.fandom.com/wiki/Photon_Lizard',
#  'https://yugioh.fandom.com/wiki/Message_in_a_Bottle',
#  'https://yugioh.fandom.com/wiki/Galaxy_Storm',
#  'https://yugioh.fandom.com/wiki/Lightserpent',
#  'https://yugioh.fandom.com/wiki/Photon_Leo',
#  'https://yugioh.fandom.com/wiki/Photon_Slasher',
#  'https://yugioh.fandom.com/wiki/Photon_Lead',
#  'https://yugioh.fandom.com/wiki/Photon_Cerberus',
#  'https://yugioh.fandom.com/wiki/Daybreaker',
#  'https://yugioh.fandom.com/wiki/Galaxy_Expedition',
#  'https://yugioh.fandom.com/wiki/Photon_Veil',
#  'https://yugioh.fandom.com/wiki/Accellight',
#  'https://yugioh.fandom.com/wiki/Number_10:_Illumiknight',
#  'https://yugioh.fandom.com/wiki/Galaxy_Wizard',
#  'https://yugioh.fandom.com/wiki/Kuriphoton',
#  'https://yugioh.fandom.com/wiki/Starliege_Paladynamo',
#  'https://yugioh.fandom.com/wiki/Photon_Crusher',
#  'https://yugioh.fandom.com/wiki/Photon_Satellite',
#  'https://yugioh.fandom.com/wiki/Lumenize']

# %%
len(get_card_urls(booster_pack_url))
# Out:
# 20

# %%
all_card_packs_url_list[328:329]
# Out:
# ['https://yugioh.fandom.com/wiki/Collection_Pack_2020']

# %%
time1 = time.perf_counter()

if __name__ == '__main__':
    # Multi-threading is used here because webscraping is an I/O bound activity, and specify max_workers
    # argument because the default value will not render the multi-threading successful
    with concurrent.futures.ThreadPoolExecutor(max_workers = 5) as executor:
        card_url_iterable = executor.map(get_card_urls, all_card_packs_url_list)
    print(f'{time.perf_counter() - time1} seconds')

# Flattening the iterable because the iterable is a list of lists, each card pack has its own list of cards
# so to combine all card urls from different card packs, we need to flatten the list
card_url_list = [item for sublist in list(card_url_iterable) for item in sublist]

# To remove duplicate URLs, since the same card can exist in multiple different packs
card_url_list = list(set(card_url_list))
card_url_list
# Out:
# 90.49897349999992 seconds
# ['https://yugioh.fandom.com/wiki/Gravekeeper%27s_Watcher',
#  'https://yugioh.fandom.com/wiki/X-Saber_Pashuul',
#  'https://yugioh.fandom.com/wiki/D.D._Jet_Iron',
#  'https://yugioh.fandom.com/wiki/Overlay_Capture',
#  'https://yugioh.fandom.com/wiki/Marauding_Captain',
#  'https://yugioh.fandom.com/wiki/Fenghuang',
#  'https://yugioh.fandom.com/wiki/Impcantation_Penciplume',
#  'https://yugioh.fandom.com/wiki/Guard_Ghost',
#  'https://yugioh.fandom.com/wiki/Tenyi_Spirit_-_Shthana',
#  'https://yugioh.fandom.com/wiki/Orcust_Crescendo',
#  'https://yugioh.fandom.com/wiki/Witch_Doctor_of_Sparta',
#  'https://yugioh.fandom.com/wiki/Mermail_Abyssocea',
#  'https://yugioh.fandom.com/wiki/Spiritual_Beast_Rampengu',
#  'https://yugioh.fandom.com/wiki/Sargasso_the_D.D._Battlefield',
#  'https://yugioh.fandom.com/wiki/Battlin%27_Boxer_Big_Bandage',
#  'https://yugioh.fandom.com/wiki/Chronomaly_Crystal_Skull',
#  'https://yugioh.fandom.com/wiki/Starship_Spy_Plane',
#  'https://yugioh.fandom.com/wiki/The_Immortal_Bushi',
#  'https://yugioh.fandom.com/wiki/Jester_Lord',
#  'https://yugioh.fandom.com/wiki/Goyo_Defender',
#  'https://yugioh.fandom.com/wiki/Bubonic_Vermin',
#  'https://yugioh.fandom.com/wiki/Sword_of_Deep-Seated',
#  'https://yugioh.fandom.com/wiki/Luster_Pendulum,_the_Dracoslayer',
#  'https://yugioh.fandom.com/wiki/Cipher_Etranger',
#  'https://yugioh.fandom.com/wiki/Statue_of_Anguish_Pattern',
#  'https://yugioh.fandom.com/wiki/Giant_Rex',
#  'https://yugioh.fandom.com/wiki/Side_Effects%3F',
#  'https://yugioh.fandom.com/wiki/Umbral_Soul',
#  'https://yugioh.fandom.com/wiki/Blackwing_-_Etesian_of_Two_Swords',
#  'https://yugioh.fandom.com/wiki/A_Feint_Plan',
#  'https://yugioh.fandom.com/wiki/Ghostrick_Mansion',
#  'https://yugioh.fandom.com/wiki/Elementsaber_Aina',
#  'https://yugioh.fandom.com/wiki/Phantom_Skyblaster',
#  'https://yugioh.fandom.com/wiki/Mechanical_Snail',
#  'https://yugioh.fandom.com/wiki/Gladiator_Beast_Vespasius',
#  'https://yugioh.fandom.com/wiki/Gladiator_Beast_Gyzarus',
#  'https://yugioh.fandom.com/wiki/Bubble_Crash',
#  'https://yugioh.fandom.com/wiki/Tsukahagi,_the_Poisonous_Mayakashi',
#  'https://yugioh.fandom.com/wiki/Tri-Blaze_Accelerator',
#  'https://yugioh.fandom.com/wiki/Assault_Blackwing_-_Sayo_the_Rain_Hider',
#  'https://yugioh.fandom.com/wiki/Evil_Eye_of_Selene',
#  'https://yugioh.fandom.com/wiki/Cyber_Archfiend',
#  'https://yugioh.fandom.com/wiki/Number_43:_Manipulator_of_Souls',
#  'https://yugioh.fandom.com/wiki/Dark_Paladin',
#  'https://yugioh.fandom.com/wiki/Scrapstorm',
#  'https://yugioh.fandom.com/wiki/Chain_Energy',
#  'https://yugioh.fandom.com/wiki/Acid_Rain',
#  'https://yugioh.fandom.com/wiki/Horn_of_Light',
#  'https://yugioh.fandom.com/wiki/Pyro_Clock_of_Destiny',
#  'https://yugioh.fandom.com/wiki/Ribbon_of_Rebirth',
#  'https://yugioh.fandom.com/wiki/Super-Nimble_Mega_Hamster',
#  'https://yugioh.fandom.com/wiki/Raidraptor_-_Blade_Burner_Falcon',
#  'https://yugioh.fandom.com/wiki/World_Legacy_Scars',
#  'https://yugioh.fandom.com/wiki/Sword_of_the_Soul-Eater',
#  'https://yugioh.fandom.com/wiki/Shadowpriestess_of_Ohm',
#  'https://yugioh.fandom.com/wiki/Evigishki_Tetrogre',
#  'https://yugioh.fandom.com/wiki/Hieratic_Dragon_of_Asar',
#  'https://yugioh.fandom.com/wiki/Eria_the_Water_Charmer,_Gentle',
#  'https://yugioh.fandom.com/wiki/Switcheroroo',
#  'https://yugioh.fandom.com/wiki/Naturia_Stinkbug',
#  'https://yugioh.fandom.com/wiki/Inverse_Universe',
#  'https://yugioh.fandom.com/wiki/Link_Apple',
#  'https://yugioh.fandom.com/wiki/World_Legacy%27s_Heart',
#  'https://yugioh.fandom.com/wiki/Fuh-Rin-Ka-Zan',
#  'https://yugioh.fandom.com/wiki/Invoked_Magellanica',
#  'https://yugioh.fandom.com/wiki/Cluster_Congester',
#  'https://yugioh.fandom.com/wiki/Dimension_Fusion_Destruction',
#  'https://yugioh.fandom.com/wiki/Des_Volstgalph',
#  'https://yugioh.fandom.com/wiki/Handcuffs_Dragon',
#  'https://yugioh.fandom.com/wiki/Cannonball_Spear_Shellfish',
#  'https://yugioh.fandom.com/wiki/Bright_Future',
#  'https://yugioh.fandom.com/wiki/Clock_Resonator',
#  'https://yugioh.fandom.com/wiki/Glory_of_the_Noble_Knights',
#  'https://yugioh.fandom.com/wiki/Fusion_Deployment',
#  'https://yugioh.fandom.com/wiki/Goblin_Circus',
#  'https://yugioh.fandom.com/wiki/Monoceros',
#  'https://yugioh.fandom.com/wiki/Kurama',
#  'https://yugioh.fandom.com/wiki/Dovelgus,_Generaider_Boss_of_Iron',
#  'https://yugioh.fandom.com/wiki/Ninjitsu_Art_of_Shadow_Sealing',
#  'https://yugioh.fandom.com/wiki/Marionette_Mite',
#  'https://yugioh.fandom.com/wiki/Onomatopia',
#  'https://yugioh.fandom.com/wiki/Creature_Swap',
#  'https://yugioh.fandom.com/wiki/Koumori_Dragon',
#  'https://yugioh.fandom.com/wiki/Earthbound_Immortal_Chacu_Challhua',
#  'https://yugioh.fandom.com/wiki/Fire_Fighting_Daruma_Doll',
#  'https://yugioh.fandom.com/wiki/Ancient_Gear_(card)',
#  'https://yugioh.fandom.com/wiki/Satellite_Warrior',
#  'https://yugioh.fandom.com/wiki/Noble_Arms_-_Caliburn',
#  'https://yugioh.fandom.com/wiki/Constellar_Sheratan',
#  'https://yugioh.fandom.com/wiki/G.B._Hunter',
#  'https://yugioh.fandom.com/wiki/Psychic_Emperor',
#  'https://yugioh.fandom.com/wiki/Poison_Chain',
#  'https://yugioh.fandom.com/wiki/Gaia_the_Fierce_Knight',
#  'https://yugioh.fandom.com/wiki/White_Dragon_Ritual',
#  'https://yugioh.fandom.com/wiki/The_Big_March_of_Animals',
#  'https://yugioh.fandom.com/wiki/Zaphion,_the_Timelord',
#  'https://yugioh.fandom.com/wiki/Black_Sonic',
#  'https://yugioh.fandom.com/wiki/Shining_Silver_Force',
#  'https://yugioh.fandom.com/wiki/Silent_Paladin',
#  'https://yugioh.fandom.com/wiki/Battle_Survivor',
#  'https://yugioh.fandom.com/wiki/Ancient_Dragon',
#  'https://yugioh.fandom.com/wiki/Evilswarm_Thunderbird',
#  'https://yugioh.fandom.com/wiki/Hunter_Dragon',
#  'https://yugioh.fandom.com/wiki/Vampire_Grimson',
#  'https://yugioh.fandom.com/wiki/Weeping_Idol',
#  'https://yugioh.fandom.com/wiki/Brotherhood_of_the_Fire_Fist_-_Horse_Prince',
#  'https://yugioh.fandom.com/wiki/Armored_Starfish',
#  'https://yugioh.fandom.com/wiki/Azure-Eyes_Silver_Dragon',
#  'https://yugioh.fandom.com/wiki/Demise,_King_of_Armageddon',
#  'https://yugioh.fandom.com/wiki/D/D/D_Human_Resources',
#  'https://yugioh.fandom.com/wiki/Invigoration',
#  'https://yugioh.fandom.com/wiki/Glorious_Illusion',
#  'https://yugioh.fandom.com/wiki/Shooting_Star_Dragon',
#  'https://yugioh.fandom.com/wiki/Metalsilver_Armor',
#  'https://yugioh.fandom.com/wiki/Yosenju_Kama_2',
#  'https://yugioh.fandom.com/wiki/Fusion_Devourer',
#  'https://yugioh.fandom.com/wiki/Graydle_Dragon',
#  'https://yugioh.fandom.com/wiki/A_Hero_Emerges',
#  'https://yugioh.fandom.com/wiki/Final_Light',
#  'https://yugioh.fandom.com/wiki/Explosive_Magician',
#  'https://yugioh.fandom.com/wiki/Sea_Lancer',
#  'https://yugioh.fandom.com/wiki/Mask_of_Restrict',
#  'https://yugioh.fandom.com/wiki/Gatekeeper',
#  'https://yugioh.fandom.com/wiki/Kaiser_Dragon',
#  'https://yugioh.fandom.com/wiki/Lightning_Punisher',
#  'https://yugioh.fandom.com/wiki/Impenetrable_Attack',
#  'https://yugioh.fandom.com/wiki/Salamangreat_Emerald_Eagle',
#  'https://yugioh.fandom.com/wiki/Primineral_Mandstrong',
#  'https://yugioh.fandom.com/wiki/Timebreaker_Magician',
#  'https://yugioh.fandom.com/wiki/Monster_Gate',
#  'https://yugioh.fandom.com/wiki/Alien_Skull',
#  'https://yugioh.fandom.com/wiki/Hieratic_Dragon_of_Tefnuit',
#  'https://yugioh.fandom.com/wiki/Drill_Barnacle',
#  'https://yugioh.fandom.com/wiki/Mara_of_the_Nordic_Alfar',
#  'https://yugioh.fandom.com/wiki/Tsuchigumo,_the_Poisonous_Mayakashi',
#  'https://yugioh.fandom.com/wiki/Zure,_Knight_of_Dark_World',
#  'https://yugioh.fandom.com/wiki/Divine_Dragon_Aquabizarre',
#  'https://yugioh.fandom.com/wiki/Tiras,_Keeper_of_Genesis',
#  'https://yugioh.fandom.com/wiki/Brionac,_Dragon_of_the_Ice_Barrier',
#  'https://yugioh.fandom.com/wiki/Vanguard_of_the_Dragon',
#  'https://yugioh.fandom.com/wiki/E%E2%98%86HERO_Pit_Boss',
#  'https://yugioh.fandom.com/wiki/Majespecter_Cat_-_Nekomata',
#  'https://yugioh.fandom.com/wiki/Dark_Spirit_Art_-_Greed',
#  'https://yugioh.fandom.com/wiki/Dice_Jar',
#  'https://yugioh.fandom.com/wiki/Mech_Bass',
#  'https://yugioh.fandom.com/wiki/Odd-Eyes_Revolution_Dragon',
#  'https://yugioh.fandom.com/wiki/Tremendous_Fire',
#  'https://yugioh.fandom.com/wiki/Heroic_Champion_-_Gandiva',
#  'https://yugioh.fandom.com/wiki/Evilswarm_Coppelia',
#  'https://yugioh.fandom.com/wiki/Brotherhood_of_the_Fire_Fist_-_Peacock',
#  'https://yugioh.fandom.com/wiki/TGX3-DX2',
#  'https://yugioh.fandom.com/wiki/Herald_of_Pure_Light',
#  'https://yugioh.fandom.com/wiki/World_Legacy_-_%22World_Shield%22',
#  'https://yugioh.fandom.com/wiki/Solemn_Wishes',
#  'https://yugioh.fandom.com/wiki/People_Running_About',
#  'https://yugioh.fandom.com/wiki/Chain_Resonator',
#  'https://yugioh.fandom.com/wiki/Beatraptor',
#  'https://yugioh.fandom.com/wiki/Silver_Sentinel',
#  'https://yugioh.fandom.com/wiki/Hyper_Hammerhead',
#  'https://yugioh.fandom.com/wiki/Searchlightman',
#  'https://yugioh.fandom.com/wiki/Gagagigo_the_Risen',
#  'https://yugioh.fandom.com/wiki/Pilgrim_Reaper',
#  'https://yugioh.fandom.com/wiki/Pikeru%27s_Circle_of_Enchantment',
#  'https://yugioh.fandom.com/wiki/Kinka-byo',
#  'https://yugioh.fandom.com/wiki/Asura_Priest',
#  'https://yugioh.fandom.com/wiki/Michion,_the_Timelord',
#  'https://yugioh.fandom.com/wiki/Bicular',
#  'https://yugioh.fandom.com/wiki/Elemental_HERO_Flash',
#  'https://yugioh.fandom.com/wiki/Vampire_Domination',
#  'https://yugioh.fandom.com/wiki/Artifact_Dagda',
#  'https://yugioh.fandom.com/wiki/Kamion,_the_Timelord',
#  'https://yugioh.fandom.com/wiki/Mekk-Knight_of_the_Morning_Star',
#  'https://yugioh.fandom.com/wiki/Armed_Dragon_LV10',
#  'https://yugioh.fandom.com/wiki/Realm_of_Danger!',
#  'https://yugioh.fandom.com/wiki/Ascending_Soul',
#  'https://yugioh.fandom.com/wiki/Link_Disciple',
#  'https://yugioh.fandom.com/wiki/Great_White',
#  'https://yugioh.fandom.com/wiki/Electric_Virus',
#  'https://yugioh.fandom.com/wiki/Tuning_Gum',
#  'https://yugioh.fandom.com/wiki/Number_C39:_Utopia_Ray_Victory',
#  'https://yugioh.fandom.com/wiki/Triple_Burst_Dragon',
#  'https://yugioh.fandom.com/wiki/Spellbook_of_Power',
#  'https://yugioh.fandom.com/wiki/Birdface',
#  'https://yugioh.fandom.com/wiki/Dancing_Elf',
#  'https://yugioh.fandom.com/wiki/Chain_Summoning',
#  'https://yugioh.fandom.com/wiki/Shiranui_Style_Success',
#  'https://yugioh.fandom.com/wiki/Bujingi_Fox',
#  'https://yugioh.fandom.com/wiki/Agave_Dragon',
#  'https://yugioh.fandom.com/wiki/Absorb_Fusion',
#  'https://yugioh.fandom.com/wiki/Prominence,_Molten_Swordsman',
#  'https://yugioh.fandom.com/wiki/Mecha_Phantom_Beast_Stealthray',
#  'https://yugioh.fandom.com/wiki/Interplanetarypurplythorny_Beast',
#  'https://yugioh.fandom.com/wiki/Makiu,_the_Magical_Mist',
#  'https://yugioh.fandom.com/wiki/Forbidden_Apocrypha',
#  'https://yugioh.fandom.com/wiki/Berserk_Dragon',
#  'https://yugioh.fandom.com/wiki/Mr._Volcano',
#  'https://yugioh.fandom.com/wiki/Transcicada',
#  'https://yugioh.fandom.com/wiki/High_Priestess_of_Prophecy',
#  'https://yugioh.fandom.com/wiki/Interplanetary_Invader_%22A%22',
#  'https://yugioh.fandom.com/wiki/World_Legacy_Monstrosity',
#  'https://yugioh.fandom.com/wiki/Diamond_Core_of_Koa%27ki_Meiru',
#  'https://yugioh.fandom.com/wiki/Yang_Zing_Path',
#  'https://yugioh.fandom.com/wiki/Junk_Box',
#  'https://yugioh.fandom.com/wiki/Phantasm_Spiral_Crash',
#  'https://yugioh.fandom.com/wiki/Ancient_Pixie_Dragon',
#  'https://yugioh.fandom.com/wiki/Barrier_Statue_of_the_Inferno',
#  'https://yugioh.fandom.com/wiki/Attention!',
#  'https://yugioh.fandom.com/wiki/Dark_Blade_the_Captain_of_the_Evil_World',
#  'https://yugioh.fandom.com/wiki/Predaplant_Cordyceps',
#  'https://yugioh.fandom.com/wiki/Clay_Charge',
#  'https://yugioh.fandom.com/wiki/Goyo_Predator',
#  'https://yugioh.fandom.com/wiki/Mind_Protector',
#  'https://yugioh.fandom.com/wiki/Naturia_Sunflower',
#  'https://yugioh.fandom.com/wiki/Infinitrack_Anchor_Drill',
#  'https://yugioh.fandom.com/wiki/Gussari_@Ignister',
#  'https://yugioh.fandom.com/wiki/Finite_Cards',
#  'https://yugioh.fandom.com/wiki/Secret_Blast',
#  'https://yugioh.fandom.com/wiki/Power_Bond',
#  'https://yugioh.fandom.com/wiki/Noble_Knight_Gawayn',
#  'https://yugioh.fandom.com/wiki/Dwimmered_Glimmer',
#  'https://yugioh.fandom.com/wiki/Fossil_Dragon_Skullgar',
#  'https://yugioh.fandom.com/wiki/Crystal_Beacon',
#  'https://yugioh.fandom.com/wiki/Kelbek',
#  'https://yugioh.fandom.com/wiki/Number_34:_Terror-Byte',
#  'https://yugioh.fandom.com/wiki/Vylon_Material',
#  'https://yugioh.fandom.com/wiki/Brotherhood_of_the_Fire_Fist_-_Raven',
#  'https://yugioh.fandom.com/wiki/Fake_Hero',
#  'https://yugioh.fandom.com/wiki/Cursed_Seal_of_the_Forbidden_Spell',
#  'https://yugioh.fandom.com/wiki/Shocktopus',
#  'https://yugioh.fandom.com/wiki/World_Reassembly',
#  'https://yugioh.fandom.com/wiki/Wind-Up_Carrier_Zenmaity',
#  'https://yugioh.fandom.com/wiki/Roaring_Ocean_Snake',
#  'https://yugioh.fandom.com/wiki/Traptrix_Nepenthes',
#  'https://yugioh.fandom.com/wiki/Gladiator_Beast_Tygerius',
#  'https://yugioh.fandom.com/wiki/Sylvan_Marshalleaf',
#  'https://yugioh.fandom.com/wiki/Leonardo%27s_Silver_Skyship',
#  'https://yugioh.fandom.com/wiki/White_Stingray',
#  'https://yugioh.fandom.com/wiki/Bubble_Blaster',
#  'https://yugioh.fandom.com/wiki/Sky_Striker_Ace_-_Kagari',
#  'https://yugioh.fandom.com/wiki/Link_Back',
#  'https://yugioh.fandom.com/wiki/Disarmament',
#  'https://yugioh.fandom.com/wiki/Slacker_Magician',
#  'https://yugioh.fandom.com/wiki/The_Wicked_Avatar',
#  'https://yugioh.fandom.com/wiki/Planet_Pathfinder',
#  'https://yugioh.fandom.com/wiki/Photon_Stream_of_Destruction',
#  'https://yugioh.fandom.com/wiki/Tsukumo_Slash',
#  'https://yugioh.fandom.com/wiki/Performance_Hurricane',
#  'https://yugioh.fandom.com/wiki/Upstart_Goblin',
#  'https://yugioh.fandom.com/wiki/Mythical_Beast_Master_Cerberus',
#  'https://yugioh.fandom.com/wiki/Meteor_of_Destruction',
#  'https://yugioh.fandom.com/wiki/Metal_Fish',
#  'https://yugioh.fandom.com/wiki/Chaos_End',
#  'https://yugioh.fandom.com/wiki/Girsu,_the_Orcust_Mekk-Knight',
#  'https://yugioh.fandom.com/wiki/Super_Team_Buddy_Force_Unite!',
#  'https://yugioh.fandom.com/wiki/Alligator%27s_Sword',
#  'https://yugioh.fandom.com/wiki/Salamangreat_Sanctuary',
#  'https://yugioh.fandom.com/wiki/Wind_Effigy',
#  'https://yugioh.fandom.com/wiki/Ascension_Sky_Dragon',
#  'https://yugioh.fandom.com/wiki/Mirror_Gate',
#  'https://yugioh.fandom.com/wiki/The_Phantom_Knights_of_Ancient_Cloak',
#  'https://yugioh.fandom.com/wiki/Radiant_Mirror_Force',
#  'https://yugioh.fandom.com/wiki/Simorgh,_Bird_of_Ancestry',
#  'https://yugioh.fandom.com/wiki/Aztekipede,_the_Worm_Warrior',
#  'https://yugioh.fandom.com/wiki/Artifact_Aegis',
#  'https://yugioh.fandom.com/wiki/Ancient_Warriors_Saga_-_Borrowing_of_Arrows',
#  'https://yugioh.fandom.com/wiki/Trap_Dustshoot',
#  'https://yugioh.fandom.com/wiki/Ms._Judge',
#  'https://yugioh.fandom.com/wiki/Seed_Cannon',
#  'https://yugioh.fandom.com/wiki/Skilled_Red_Magician',
#  'https://yugioh.fandom.com/wiki/Tenma_the_Sky_Star',
#  'https://yugioh.fandom.com/wiki/Violet_Witch',
#  'https://yugioh.fandom.com/wiki/Litmus_Doom_Ritual',
#  'https://yugioh.fandom.com/wiki/Raptor%27s_Gust',
#  'https://yugioh.fandom.com/wiki/Tengu,_the_Winged_Mayakashi',
#  'https://yugioh.fandom.com/wiki/Fairy_Dragon',
#  'https://yugioh.fandom.com/wiki/Wavering_Eyes',
#  'https://yugioh.fandom.com/wiki/Formula_Synchron',
#  'https://yugioh.fandom.com/wiki/Super_Defense_Robot_Monki',
#  'https://yugioh.fandom.com/wiki/Doomdog_Octhros',
#  'https://yugioh.fandom.com/wiki/Atlantean_Pikeman',
#  'https://yugioh.fandom.com/wiki/Performapal_Stamp_Turtle',
#  'https://yugioh.fandom.com/wiki/Psycho_Gigacyber',
#  'https://yugioh.fandom.com/wiki/Venom_Snake',
#  'https://yugioh.fandom.com/wiki/Dragoroar',
#  'https://yugioh.fandom.com/wiki/Goddess_Skuld%27s_Oracle',
#  'https://yugioh.fandom.com/wiki/Unchained_Twins_-_Rakea',
#  'https://yugioh.fandom.com/wiki/Destiny_HERO_-_Disk_Commander',
#  'https://yugioh.fandom.com/wiki/Zubababancho_Gagagacoat',
#  'https://yugioh.fandom.com/wiki/Guerilla_Kite',
#  'https://yugioh.fandom.com/wiki/Vendread_Reorigin',
#  'https://yugioh.fandom.com/wiki/Question',
#  'https://yugioh.fandom.com/wiki/Superheavy_Samurai_Prepped_Defense',
#  'https://yugioh.fandom.com/wiki/Miracle%27s_Wake',
#  'https://yugioh.fandom.com/wiki/D.D._Seeker',
#  'https://yugioh.fandom.com/wiki/Stoic_Challenge',
#  'https://yugioh.fandom.com/wiki/XX-Saber_Gardestrike',
#  'https://yugioh.fandom.com/wiki/Igknight_Champion',
#  'https://yugioh.fandom.com/wiki/Water_Magician',
#  'https://yugioh.fandom.com/wiki/Maji-Gire_Panda',
#  'https://yugioh.fandom.com/wiki/Fluffal_Mouse',
#  'https://yugioh.fandom.com/wiki/Ghostrick_Parade',
#  'https://yugioh.fandom.com/wiki/Performapal_Gongato',
#  'https://yugioh.fandom.com/wiki/Beautunaful_Princess',
#  'https://yugioh.fandom.com/wiki/Graydle_Slime',
#  'https://yugioh.fandom.com/wiki/World_Legacy_-_%22World_Key%22',
#  'https://yugioh.fandom.com/wiki/Mystical_Knight_of_Jackal',
#  'https://yugioh.fandom.com/wiki/Divine_Wrath',
#  'https://yugioh.fandom.com/wiki/Galaxy-Eyes_Full_Armor_Photon_Dragon',
#  'https://yugioh.fandom.com/wiki/Castel,_the_Skyblaster_Musketeer',
#  'https://yugioh.fandom.com/wiki/Zefraniu,_Secret_of_the_Yang_Zing',
#  'https://yugioh.fandom.com/wiki/Fairy_of_the_Fountain',
#  'https://yugioh.fandom.com/wiki/Synchron_Explorer',
#  'https://yugioh.fandom.com/wiki/Dragon_Buster_Destruction_Sword',
#  'https://yugioh.fandom.com/wiki/Double_Payback',
#  'https://yugioh.fandom.com/wiki/Dreamsprite',
#  'https://yugioh.fandom.com/wiki/Amores_of_Prophecy',
#  'https://yugioh.fandom.com/wiki/Giant_Red_Seasnake',
#  'https://yugioh.fandom.com/wiki/Geargiauger',
#  'https://yugioh.fandom.com/wiki/Book_of_Moon',
#  'https://yugioh.fandom.com/wiki/Burning_Soul_(card)',
#  'https://yugioh.fandom.com/wiki/The_Big_Saturn',
#  'https://yugioh.fandom.com/wiki/Cynet_Conflict',
#  'https://yugioh.fandom.com/wiki/Number_46:_Dragluon',
#  'https://yugioh.fandom.com/wiki/Paleozoic_Anomalocaris',
#  'https://yugioh.fandom.com/wiki/Vendread_Battlelord',
#  'https://yugioh.fandom.com/wiki/Assault_Sentinel',
#  'https://yugioh.fandom.com/wiki/Heroic_Challenger_-_Thousand_Blade',
#  'https://yugioh.fandom.com/wiki/Burning_Bamboo_Sword',
#  'https://yugioh.fandom.com/wiki/Rider_of_the_Storm_Winds',
#  'https://yugioh.fandom.com/wiki/Damage_Condenser',
#  'https://yugioh.fandom.com/wiki/Combo_Master',
#  'https://yugioh.fandom.com/wiki/Laval_Burner',
#  'https://yugioh.fandom.com/wiki/Xyz_Remora',
#  'https://yugioh.fandom.com/wiki/Number_3:_Numeron_Gate_Trini',
#  'https://yugioh.fandom.com/wiki/Fiend%27s_Hand',
#  'https://yugioh.fandom.com/wiki/Lady_of_Faith',
#  'https://yugioh.fandom.com/wiki/Valkyrie_Zweite',
#  'https://yugioh.fandom.com/wiki/Unicycular',
#  'https://yugioh.fandom.com/wiki/Dust_Barrier',
#  'https://yugioh.fandom.com/wiki/Symphonic_Warrior_Synthess',
#  'https://yugioh.fandom.com/wiki/Decayed_Commander',
#  'https://yugioh.fandom.com/wiki/Armor_Exe',
#  'https://yugioh.fandom.com/wiki/Nightmare_Horse',
#  'https://yugioh.fandom.com/wiki/Kozmo_Dark_Planet',
#  'https://yugioh.fandom.com/wiki/F.A._Auto_Navigator',
#  'https://yugioh.fandom.com/wiki/Cyber_Shield',
#  'https://yugioh.fandom.com/wiki/Wrecker_Panda',
#  'https://yugioh.fandom.com/wiki/Majestic_Star_Dragon',
#  'https://yugioh.fandom.com/wiki/Jowls_of_Dark_Demise',
#  'https://yugioh.fandom.com/wiki/Metal_Reflect_Slime',
#  'https://yugioh.fandom.com/wiki/Mythical_Bestiary',
#  'https://yugioh.fandom.com/wiki/Infinitrack_Earth_Slicer',
#  'https://yugioh.fandom.com/wiki/Meklord_Army_of_Wisel',
#  'https://yugioh.fandom.com/wiki/Gouki_Riscorpio',
#  'https://yugioh.fandom.com/wiki/Gift_Card',
#  'https://yugioh.fandom.com/wiki/Madolche_Mewfeuille',
#  'https://yugioh.fandom.com/wiki/Cyberse_Synchron',
#  'https://yugioh.fandom.com/wiki/Unending_Nightmare',
#  'https://yugioh.fandom.com/wiki/Chain_Destruction',
#  'https://yugioh.fandom.com/wiki/Fushioh_Richie',
#  'https://yugioh.fandom.com/wiki/Mysterious_Guard',
#  'https://yugioh.fandom.com/wiki/Wattfox',
#  'https://yugioh.fandom.com/wiki/Thunderclap_Skywolf',
#  'https://yugioh.fandom.com/wiki/Frightfur_Meister',
#  'https://yugioh.fandom.com/wiki/Raptor_Wing_Strike',
#  'https://yugioh.fandom.com/wiki/Ameba',
#  'https://yugioh.fandom.com/wiki/Ritual_Beast_Ulti-Pettlephin',
#  'https://yugioh.fandom.com/wiki/Axe_of_Fools',
#  'https://yugioh.fandom.com/wiki/Seal_of_the_Ancients',
#  'https://yugioh.fandom.com/wiki/Zubaba_Knight',
#  'https://yugioh.fandom.com/wiki/Royal_Swamp_Eel',
#  'https://yugioh.fandom.com/wiki/XX-Saber_Boggart_Knight',
#  'https://yugioh.fandom.com/wiki/Bahamut_Shark',
#  'https://yugioh.fandom.com/wiki/Lucky_Trinket',
#  'https://yugioh.fandom.com/wiki/Pitch-Black_Warwolf',
#  'https://yugioh.fandom.com/wiki/Ancient_Warriors_-_Eccentric_Lu_Jing',
#  'https://yugioh.fandom.com/wiki/Cyberdark_Inferno',
#  'https://yugioh.fandom.com/wiki/Sphinx_Teleia',
#  'https://yugioh.fandom.com/wiki/Dark_Scorpion_Combination',
#  'https://yugioh.fandom.com/wiki/Contract_with_Exodia',
#  'https://yugioh.fandom.com/wiki/Eldlixir_of_Scarlet_Sanguine',
#  'https://yugioh.fandom.com/wiki/Samsara,_Dragon_of_Rebirth',
#  'https://yugioh.fandom.com/wiki/Metamorphortress',
#  'https://yugioh.fandom.com/wiki/Hysteric_Party',
#  'https://yugioh.fandom.com/wiki/Masked_Dragon',
#  'https://yugioh.fandom.com/wiki/Wattcube',
#  'https://yugioh.fandom.com/wiki/Mirage_Dragon',
#  'https://yugioh.fandom.com/wiki/Evil_Dragon_Ananta',
#  'https://yugioh.fandom.com/wiki/Reptilianne_Rage',
#  'https://yugioh.fandom.com/wiki/Bonding_-_DHO',
#  'https://yugioh.fandom.com/wiki/Last_Chapter_of_the_Noble_Knights',
#  'https://yugioh.fandom.com/wiki/Synthesis_Spell',
#  'https://yugioh.fandom.com/wiki/Ritual_Beast_Tamer_Lara',
#  'https://yugioh.fandom.com/wiki/Meliae_of_the_Trees',
#  'https://yugioh.fandom.com/wiki/Evil_Eye_of_Gorgoneio',
#  'https://yugioh.fandom.com/wiki/Cubic_Rebirth',
#  'https://yugioh.fandom.com/wiki/Brilliant_Spark',
#  'https://yugioh.fandom.com/wiki/Hazy_Flame_Hyppogrif',
#  'https://yugioh.fandom.com/wiki/One_with_the_Sun_God',
#  'https://yugioh.fandom.com/wiki/Scrap_Dragon',
#  'https://yugioh.fandom.com/wiki/Toon_Summoned_Skull',
#  'https://yugioh.fandom.com/wiki/Destiny_HERO_-_Blade_Master',
#  'https://yugioh.fandom.com/wiki/Fairy_Knight_Ingunar',
#  'https://yugioh.fandom.com/wiki/The_Law_of_the_Normal',
#  'https://yugioh.fandom.com/wiki/Snatch_Steal',
#  'https://yugioh.fandom.com/wiki/Lady_Assailant_of_Flames',
#  'https://yugioh.fandom.com/wiki/Dark_Sanctuary',
#  'https://yugioh.fandom.com/wiki/Reckless_Greed',
#  'https://yugioh.fandom.com/wiki/Frightfur_Daredevil',
#  'https://yugioh.fandom.com/wiki/Numeron_Wall',
#  'https://yugioh.fandom.com/wiki/Diana_the_Light_Spirit',
#  'https://yugioh.fandom.com/wiki/Odd-Eyes_Wing_Dragon',
#  'https://yugioh.fandom.com/wiki/Performapal_Revival',
#  'https://yugioh.fandom.com/wiki/Localized_Tornado',
#  'https://yugioh.fandom.com/wiki/Angraecum_Umbrella',
#  'https://yugioh.fandom.com/wiki/Fortune_Lady_Past',
#  'https://yugioh.fandom.com/wiki/The_Emperor%27s_Holiday',
#  'https://yugioh.fandom.com/wiki/Deskbot_007',
#  'https://yugioh.fandom.com/wiki/Number_5:_Doom_Chimera_Dragon',
#  'https://yugioh.fandom.com/wiki/Shinobird_Crow',
#  'https://yugioh.fandom.com/wiki/Brotherhood_of_the_Fire_Fist_-_Panda',
#  'https://yugioh.fandom.com/wiki/Meklord_Assembly',
#  'https://yugioh.fandom.com/wiki/Void_Trap_Hole',
#  'https://yugioh.fandom.com/wiki/Engraver_of_the_Mark',
#  'https://yugioh.fandom.com/wiki/R_-_Righteous_Justice',
#  'https://yugioh.fandom.com/wiki/Loki,_Lord_of_the_Aesir',
#  'https://yugioh.fandom.com/wiki/Chronomaly_Mud_Golem',
#  'https://yugioh.fandom.com/wiki/Dragon%27s_Fighting_Spirit',
#  'https://yugioh.fandom.com/wiki/Magician_of_Dark_Illusion',
#  'https://yugioh.fandom.com/wiki/Number_81:_Superdreadnought_Rail_Cannon_Super_Dora',
#  'https://yugioh.fandom.com/wiki/Gouki_Moonsault',
#  'https://yugioh.fandom.com/wiki/Eisbahn',
#  'https://yugioh.fandom.com/wiki/The_Phantom_Knights_of_Lost_Vambrace',
#  'https://yugioh.fandom.com/wiki/Luminous_Soldier',
#  'https://yugioh.fandom.com/wiki/Flower_Cardian_Paulownia_with_Phoenix',
#  'https://yugioh.fandom.com/wiki/Aurora_Paragon',
#  'https://yugioh.fandom.com/wiki/Mithra_the_Thunder_Vassal',
#  'https://yugioh.fandom.com/wiki/Metaphys_Dimension',
#  'https://yugioh.fandom.com/wiki/Crimson_Nova_Trinity_the_Dark_Cubic_Lord',
#  'https://yugioh.fandom.com/wiki/Boompoline!!',
#  'https://yugioh.fandom.com/wiki/Legend_of_Heart',
#  'https://yugioh.fandom.com/wiki/Heraldic_Beast_Berners_Falcon',
#  'https://yugioh.fandom.com/wiki/Infernity_Knight',
#  'https://yugioh.fandom.com/wiki/Topologic_Trisbaena',
#  'https://yugioh.fandom.com/wiki/Supreme_King_Dragon_Starving_Venom',
#  'https://yugioh.fandom.com/wiki/Artifacts_Unleashed',
#  'https://yugioh.fandom.com/wiki/Wattbetta',
#  'https://yugioh.fandom.com/wiki/Phantasmal_Martyrs',
#  'https://yugioh.fandom.com/wiki/Speedroid_Dominobutterfly',
#  'https://yugioh.fandom.com/wiki/Adreus,_Keeper_of_Armageddon',
#  'https://yugioh.fandom.com/wiki/Ultimate_Fire_Formation_-_Seito',
#  'https://yugioh.fandom.com/wiki/Spell_Gear',
#  'https://yugioh.fandom.com/wiki/Puppet_Parade',
#  'https://yugioh.fandom.com/wiki/The_Huge_Revolution_is_Over',
#  'https://yugioh.fandom.com/wiki/Union_Carrier',
#  'https://yugioh.fandom.com/wiki/Deskbot_002',
#  'https://yugioh.fandom.com/wiki/White_Hole',
#  'https://yugioh.fandom.com/wiki/Photon_Wyvern',
#  'https://yugioh.fandom.com/wiki/Red-Eyes_Fusion',
#  'https://yugioh.fandom.com/wiki/Dododo_Bot',
#  'https://yugioh.fandom.com/wiki/Photon_Sanctuary',
#  'https://yugioh.fandom.com/wiki/Counselor_Lily',
#  'https://yugioh.fandom.com/wiki/Neo_Space_Pathfinder',
#  'https://yugioh.fandom.com/wiki/Ritual_Cage',
#  'https://yugioh.fandom.com/wiki/Elemental_HERO_Ice_Edge',
#  'https://yugioh.fandom.com/wiki/Alien_Psychic',
#  'https://yugioh.fandom.com/wiki/Lightsworn_Sabre',
#  'https://yugioh.fandom.com/wiki/Guardragon_Reincarnation',
#  'https://yugioh.fandom.com/wiki/Vendread_Chimera',
#  'https://yugioh.fandom.com/wiki/Magic_Planter',
#  'https://yugioh.fandom.com/wiki/PSY-Framegear_Beta',
#  'https://yugioh.fandom.com/wiki/Orichalcos_Shunoros',
#  'https://yugioh.fandom.com/wiki/Aromage_Marjoram',
#  'https://yugioh.fandom.com/wiki/Onomatopaira',
#  'https://yugioh.fandom.com/wiki/Shiranui_Style_Swallow%27s_Slash',
#  'https://yugioh.fandom.com/wiki/Hazy_Glory',
#  'https://yugioh.fandom.com/wiki/Achacha_Chanbara',
#  'https://yugioh.fandom.com/wiki/Krystal_Dragon',
#  'https://yugioh.fandom.com/wiki/Uraby',
#  'https://yugioh.fandom.com/wiki/Lyrilusc_-_Turquoise_Warbler',
#  'https://yugioh.fandom.com/wiki/Alluring_Mirror_Split',
#  'https://yugioh.fandom.com/wiki/Laser_Cannon_Armor',
#  'https://yugioh.fandom.com/wiki/Madolche_Anjelly',
#  'https://yugioh.fandom.com/wiki/Topologic_Bomber_Dragon',
#  'https://yugioh.fandom.com/wiki/Don_Zaloog',
#  'https://yugioh.fandom.com/wiki/Dark_Magician_Knight',
#  'https://yugioh.fandom.com/wiki/Night_Wing_Sorceress',
#  'https://yugioh.fandom.com/wiki/Phantom_Beast_Rock-Lizard',
#  'https://yugioh.fandom.com/wiki/Buster_Gundil_the_Cubic_Behemoth',
#  'https://yugioh.fandom.com/wiki/Shark_Stickers',
#  'https://yugioh.fandom.com/wiki/Beast_King_Barbaros',
#  'https://yugioh.fandom.com/wiki/Crystal_Wing_Synchro_Dragon',
#  'https://yugioh.fandom.com/wiki/Cyber_Dragon_Zwei',
#  'https://yugioh.fandom.com/wiki/Darklord_Marie',
#  'https://yugioh.fandom.com/wiki/Tyrant%27s_Tantrum',
#  'https://yugioh.fandom.com/wiki/Tindangle_Hound',
#  'https://yugioh.fandom.com/wiki/Light_Dragon_@Ignister',
#  'https://yugioh.fandom.com/wiki/ZW_-_Ultimate_Shield',
#  'https://yugioh.fandom.com/wiki/Horus_the_Black_Flame_Dragon_LV8',
#  'https://yugioh.fandom.com/wiki/Geargiano',
#  'https://yugioh.fandom.com/wiki/Infinite_Impermanence',
#  'https://yugioh.fandom.com/wiki/Mahunder',
#  'https://yugioh.fandom.com/wiki/Rank-Up-Magic_Doom_Double_Force',
#  'https://yugioh.fandom.com/wiki/Gladiator_Beast%27s_Battle_Halberd',
#  'https://yugioh.fandom.com/wiki/Gem-Knight_Master_Diamond',
#  'https://yugioh.fandom.com/wiki/Toon_Kingdom',
#  'https://yugioh.fandom.com/wiki/Zombowwow',
#  'https://yugioh.fandom.com/wiki/Blackwing_-_Fane_the_Steel_Chain',
#  'https://yugioh.fandom.com/wiki/Zodiac_Sign',
#  'https://yugioh.fandom.com/wiki/Pendulum_Fusion',
#  'https://yugioh.fandom.com/wiki/Gokibore',
#  'https://yugioh.fandom.com/wiki/Shuttleroid',
#  'https://yugioh.fandom.com/wiki/Night_Papilloperative',
#  'https://yugioh.fandom.com/wiki/U.A._Dreadnought_Dunker',
#  'https://yugioh.fandom.com/wiki/Primal_Seed',
#  'https://yugioh.fandom.com/wiki/Kozmo_Dark_Eclipser',
#  'https://yugioh.fandom.com/wiki/Hundred_Eyes_Dragon',
#  'https://yugioh.fandom.com/wiki/Miniaturize',
#  'https://yugioh.fandom.com/wiki/D/D/D_Resource_Management',
#  'https://yugioh.fandom.com/wiki/Gouki_Destroy_Ogre',
#  'https://yugioh.fandom.com/wiki/Elemental_HERO_Wildedge',
#  'https://yugioh.fandom.com/wiki/Battlin%27_Boxer_Shadow',
#  'https://yugioh.fandom.com/wiki/Cyberse_Converter',
#  'https://yugioh.fandom.com/wiki/Dark_Garnex_the_Cubic_Beast',
#  'https://yugioh.fandom.com/wiki/Constellar_Ptolemy_M7',
#  'https://yugioh.fandom.com/wiki/Inzektor_Giga-Mantis',
#  'https://yugioh.fandom.com/wiki/Ryu_Okami',
#  'https://yugioh.fandom.com/wiki/Memories_of_Hope',
#  'https://yugioh.fandom.com/wiki/Chamberlain_of_the_Six_Samurai',
#  'https://yugioh.fandom.com/wiki/Protector_with_Eyes_of_Blue',
#  'https://yugioh.fandom.com/wiki/Artifact_Mjollnir',
#  'https://yugioh.fandom.com/wiki/Laval_Forest_Sprite',
#  'https://yugioh.fandom.com/wiki/Rare_Fish',
#  'https://yugioh.fandom.com/wiki/Salamangreat_Almiraj',
#  'https://yugioh.fandom.com/wiki/Sage_of_Stillness',
#  'https://yugioh.fandom.com/wiki/Powerful_Rebirth',
#  'https://yugioh.fandom.com/wiki/Gusto_Codor',
#  'https://yugioh.fandom.com/wiki/Firebird',
#  'https://yugioh.fandom.com/wiki/Crystron_Smiger',
#  'https://yugioh.fandom.com/wiki/Kalantosa,_Mystical_Beast_of_the_Forest',
#  'https://yugioh.fandom.com/wiki/Re-Fusion',
#  'https://yugioh.fandom.com/wiki/Dark_Horizon',
#  'https://yugioh.fandom.com/wiki/Instant_Neo_Space',
#  'https://yugioh.fandom.com/wiki/Danger!_Disaster!',
#  'https://yugioh.fandom.com/wiki/Simorgh,_Lord_of_the_Storm',
#  'https://yugioh.fandom.com/wiki/Grave_Squirmer',
#  'https://yugioh.fandom.com/wiki/Masked_Beast_Des_Gardius',
#  'https://yugioh.fandom.com/wiki/Trap_of_Board_Eraser',
#  'https://yugioh.fandom.com/wiki/Dotedotengu',
#  'https://yugioh.fandom.com/wiki/D-Boyz',
#  'https://yugioh.fandom.com/wiki/Ultra_Evolution_Pill',
#  'https://yugioh.fandom.com/wiki/Dr._Frankenderp',
#  'https://yugioh.fandom.com/wiki/Nekroz_Kaleidoscope',
#  'https://yugioh.fandom.com/wiki/Evo-Miracle',
#  'https://yugioh.fandom.com/wiki/Ryu-Kishin',
#  'https://yugioh.fandom.com/wiki/Call_of_the_Atlanteans',
#  'https://yugioh.fandom.com/wiki/Gladiator_Beast_Attorix',
#  'https://yugioh.fandom.com/wiki/Nekroz_of_Gungnir',
#  'https://yugioh.fandom.com/wiki/Needle_Worm',
#  'https://yugioh.fandom.com/wiki/Super_Anti-Kaiju_War_Machine_Mecha-Thunder-King',
#  'https://yugioh.fandom.com/wiki/Number_XX:_Utopic_Dark_Infinity',
#  'https://yugioh.fandom.com/wiki/Ruffian_Railcar',
#  'https://yugioh.fandom.com/wiki/Abyss_Actor_-_Wild_Hope',
#  'https://yugioh.fandom.com/wiki/Performage_Mirror_Conductor',
#  'https://yugioh.fandom.com/wiki/Marincess_Blue_Tang',
#  'https://yugioh.fandom.com/wiki/Mermail_Abyssbalaen',
#  'https://yugioh.fandom.com/wiki/Dharma-Eye_Magician',
#  'https://yugioh.fandom.com/wiki/Bujingi_Sinyou',
#  'https://yugioh.fandom.com/wiki/Raigeki_Break',
#  'https://yugioh.fandom.com/wiki/Cauldron_of_the_Old_Man',
#  'https://yugioh.fandom.com/wiki/Snakeyashi',
#  'https://yugioh.fandom.com/wiki/Cross-Sheep',
#  'https://yugioh.fandom.com/wiki/Mermail_Abyssgaios',
#  'https://yugioh.fandom.com/wiki/Emblem_of_Dragon_Destroyer',
#  'https://yugioh.fandom.com/wiki/D/D_Savant_Galilei',
#  'https://yugioh.fandom.com/wiki/Jowgen_the_Spiritualist',
#  'https://yugioh.fandom.com/wiki/Mystical_Refpanel',
#  'https://yugioh.fandom.com/wiki/Speedlift',
#  'https://yugioh.fandom.com/wiki/Ritual_Weapon',
#  'https://yugioh.fandom.com/wiki/Pestilence',
#  'https://yugioh.fandom.com/wiki/Chosen_by_the_World_Chalice',
#  'https://yugioh.fandom.com/wiki/Yang_Zing_Unleashed',
#  'https://yugioh.fandom.com/wiki/Moon_Envoy',
#  'https://yugioh.fandom.com/wiki/Earthshattering_Event',
#  'https://yugioh.fandom.com/wiki/Deal_of_Phantom',
#  'https://yugioh.fandom.com/wiki/Time_Thief_Startup',
#  'https://yugioh.fandom.com/wiki/Gladiator_Beast_Samnite',
#  'https://yugioh.fandom.com/wiki/Spark_Blaster',
#  'https://yugioh.fandom.com/wiki/Backup_Soldier',
#  'https://yugioh.fandom.com/wiki/Crystal_Beast_Amber_Mammoth',
#  'https://yugioh.fandom.com/wiki/Hibikime',
#  'https://yugioh.fandom.com/wiki/Moon_Dance_Ritual',
#  'https://yugioh.fandom.com/wiki/Axe_Dragonute',
#  'https://yugioh.fandom.com/wiki/Wandering_King_Wildwind',
#  'https://yugioh.fandom.com/wiki/Striping_Partner',
#  'https://yugioh.fandom.com/wiki/The_Book_of_the_Law',
#  'https://yugioh.fandom.com/wiki/D/D/D_Contract_Change',
#  'https://yugioh.fandom.com/wiki/Sasuke_Samurai_4',
#  'https://yugioh.fandom.com/wiki/White_Mirror',
#  'https://yugioh.fandom.com/wiki/Swallow%27s_Nest',
#  'https://yugioh.fandom.com/wiki/Twin-Barrel_Dragon',
#  'https://yugioh.fandom.com/wiki/Dragon_Ravine',
#  'https://yugioh.fandom.com/wiki/Preparation_of_Rites',
#  'https://yugioh.fandom.com/wiki/Diamond_Dire_Wolf',
#  'https://yugioh.fandom.com/wiki/Alien_Hypno',
#  'https://yugioh.fandom.com/wiki/Galaxy-Eyes_Cloudragon',
#  'https://yugioh.fandom.com/wiki/Rare_Metalmorph',
#  'https://yugioh.fandom.com/wiki/Symbols_of_Duty',
#  'https://yugioh.fandom.com/wiki/Barrel_Dragon',
#  'https://yugioh.fandom.com/wiki/Vylon_Tesseract',
#  'https://yugioh.fandom.com/wiki/Flower_Cardian_Lightflare',
#  'https://yugioh.fandom.com/wiki/Gravity_Warrior',
#  'https://yugioh.fandom.com/wiki/Chrysalis_Larva',
#  'https://yugioh.fandom.com/wiki/Silent_Sword_Slash',
#  'https://yugioh.fandom.com/wiki/Nephthys,_the_Sacred_Flame',
#  'https://yugioh.fandom.com/wiki/Platinum_Gadget',
#  'https://yugioh.fandom.com/wiki/Chronomaly_Moai_Carrier',
#  'https://yugioh.fandom.com/wiki/Witchcrafter_Golem_Aruru',
#  'https://yugioh.fandom.com/wiki/Crystal_Beast_Sapphire_Pegasus',
#  'https://yugioh.fandom.com/wiki/Harpie%27s_Pet_Dragon',
#  'https://yugioh.fandom.com/wiki/Drop_Off',
#  'https://yugioh.fandom.com/wiki/Reprodocus',
#  'https://yugioh.fandom.com/wiki/Gishki_Noellia',
#  'https://yugioh.fandom.com/wiki/Delta_Tri',
#  'https://yugioh.fandom.com/wiki/Fortune_Fairy_Chee',
#  'https://yugioh.fandom.com/wiki/El_Shaddoll_Anoyatyllis',
#  'https://yugioh.fandom.com/wiki/Atlantean_Heavy_Infantry',
#  'https://yugioh.fandom.com/wiki/Number_C103:_Ragnafinity',
#  'https://yugioh.fandom.com/wiki/Dark_Magic_Curtain',
#  'https://yugioh.fandom.com/wiki/Apple_Magician_Girl',
#  'https://yugioh.fandom.com/wiki/Fortune_Lady_Calling',
#  'https://yugioh.fandom.com/wiki/Windwitch_-_Glass_Bell',
#  'https://yugioh.fandom.com/wiki/The_Black_Stone_of_Legend',
#  'https://yugioh.fandom.com/wiki/Gemini_Booster',
#  'https://yugioh.fandom.com/wiki/Deskbot_003',
#  'https://yugioh.fandom.com/wiki/Protocol_Gardna',
#  'https://yugioh.fandom.com/wiki/Jurrac_Stauriko',
#  'https://yugioh.fandom.com/wiki/Reactan,_Dragon_Ruler_of_Pebbles',
#  'https://yugioh.fandom.com/wiki/Steelswarm_Genome',
#  'https://yugioh.fandom.com/wiki/Chorus_of_Sanctuary',
#  'https://yugioh.fandom.com/wiki/Sonic_Jammer',
#  'https://yugioh.fandom.com/wiki/Soul_Charge',
#  'https://yugioh.fandom.com/wiki/Clashing_Souls',
#  'https://yugioh.fandom.com/wiki/Shinobird%27s_Calling',
#  'https://yugioh.fandom.com/wiki/Star_Seraph_Scale',
#  'https://yugioh.fandom.com/wiki/Gouki_Twistcobra',
#  'https://yugioh.fandom.com/wiki/Emperor_Maju_Garzett',
#  'https://yugioh.fandom.com/wiki/Adamancipator_Laputite',
#  'https://yugioh.fandom.com/wiki/Performapal_Skullcrobat_Joker',
#  'https://yugioh.fandom.com/wiki/CXyz_Barian_Hope',
#  'https://yugioh.fandom.com/wiki/Ancient_Gear_Fusion',
#  'https://yugioh.fandom.com/wiki/T.G._Catapult_Dragon',
#  'https://yugioh.fandom.com/wiki/Skull_Invitation',
#  'https://yugioh.fandom.com/wiki/Giant_Axe_Mummy',
#  'https://yugioh.fandom.com/wiki/Royal_Oppression',
#  'https://yugioh.fandom.com/wiki/Apoqliphort_Skybase',
#  'https://yugioh.fandom.com/wiki/Gravekeeper%27s_Visionary',
#  'https://yugioh.fandom.com/wiki/Sphere_of_Chaos',
#  'https://yugioh.fandom.com/wiki/Dried_Winds',
#  'https://yugioh.fandom.com/wiki/Jurrac_Velo',
#  'https://yugioh.fandom.com/wiki/Bite_Bug',
#  'https://yugioh.fandom.com/wiki/Infernal_Incinerator',
#  'https://yugioh.fandom.com/wiki/Amazoness_Shamanism',
#  'https://yugioh.fandom.com/wiki/Samsara',
#  'https://yugioh.fandom.com/wiki/Evo-Branch',
#  'https://yugioh.fandom.com/wiki/Blackwing_-_Gofu_the_Vague_Shadow',
#  'https://yugioh.fandom.com/wiki/Destiny_HERO_-_Dark_Angel',
#  'https://yugioh.fandom.com/wiki/Zolga',
#  'https://yugioh.fandom.com/wiki/Mekk-Knight_Red_Moon',
#  'https://yugioh.fandom.com/wiki/Supay',
#  'https://yugioh.fandom.com/wiki/Ojama_King',
#  'https://yugioh.fandom.com/wiki/Symbol_of_Friendship',
#  'https://yugioh.fandom.com/wiki/Link_Spider',
#  'https://yugioh.fandom.com/wiki/Dark_Resonator',
#  'https://yugioh.fandom.com/wiki/Soul_Levy',
#  'https://yugioh.fandom.com/wiki/Naturia_Horneedle',
#  'https://yugioh.fandom.com/wiki/Number_C102:_Archfiend_Seraph',
#  'https://yugioh.fandom.com/wiki/Flash_Assailant',
#  'https://yugioh.fandom.com/wiki/Beast-Warrior_Puma',
#  'https://yugioh.fandom.com/wiki/Dark_Horus',
#  'https://yugioh.fandom.com/wiki/Silent_Swordsman',
#  'https://yugioh.fandom.com/wiki/Steelswarm_Roach',
#  'https://yugioh.fandom.com/wiki/Lady_of_D.',
#  'https://yugioh.fandom.com/wiki/Ganigumo',
#  'https://yugioh.fandom.com/wiki/Galaxy_Storm',
#  'https://yugioh.fandom.com/wiki/Triamid_Fortress',
#  'https://yugioh.fandom.com/wiki/Elemental_HERO_Voltic',
#  'https://yugioh.fandom.com/wiki/Karakuri_Soldier_mdl_236_%22Nisamu%22',
#  'https://yugioh.fandom.com/wiki/Bururu_@Ignister',
#  'https://yugioh.fandom.com/wiki/Block_Attack',
#  'https://yugioh.fandom.com/wiki/Brotherhood_of_the_Fire_Fist_-_Caribou',
#  'https://yugioh.fandom.com/wiki/Zoodiac_Tigermortar',
#  'https://yugioh.fandom.com/wiki/Toon_Cyber_Dragon',
#  'https://yugioh.fandom.com/wiki/F.A._Pit_Stop',
#  'https://yugioh.fandom.com/wiki/8-Claws_Scorpion',
#  'https://yugioh.fandom.com/wiki/Firewall_Guardian',
#  'https://yugioh.fandom.com/wiki/Genex_Ally_Powercell',
#  'https://yugioh.fandom.com/wiki/Toon_Defense',
#  'https://yugioh.fandom.com/wiki/Snapdragon',
#  'https://yugioh.fandom.com/wiki/Ancient_Tool',
#  'https://yugioh.fandom.com/wiki/Amazing_Pendulum',
#  'https://yugioh.fandom.com/wiki/Phantom_Dewan',
#  'https://yugioh.fandom.com/wiki/Buster_Blaster',
#  'https://yugioh.fandom.com/wiki/Eternal_Dread',
#  'https://yugioh.fandom.com/wiki/Sky_Striker_Maneuver_-_Jamming_Waves!',
#  'https://yugioh.fandom.com/wiki/Elemental_HERO_Electrum',
#  'https://yugioh.fandom.com/wiki/Zefraxi,_Treasure_of_the_Yang_Zing',
#  'https://yugioh.fandom.com/wiki/At_One_With_the_Sword',
#  'https://yugioh.fandom.com/wiki/Mutually_Affured_Destruction',
#  'https://yugioh.fandom.com/wiki/Forced_Ceasefire',
#  'https://yugioh.fandom.com/wiki/Number_91:_Thunder_Spark_Dragon',
#  'https://yugioh.fandom.com/wiki/Artorigus,_King_of_the_Noble_Knights',
#  'https://yugioh.fandom.com/wiki/Back-Up_Rider',
#  'https://yugioh.fandom.com/wiki/The_Winged_Dragon_of_Ra',
#  'https://yugioh.fandom.com/wiki/T.G._Gear_Zombie',
#  'https://yugioh.fandom.com/wiki/Life_Equalizer',
#  'https://yugioh.fandom.com/wiki/Artifact_Sanctum',
#  'https://yugioh.fandom.com/wiki/Revendread_Slayer',
#  'https://yugioh.fandom.com/wiki/Testudo_erat_Numen',
#  'https://yugioh.fandom.com/wiki/Predaplanet',
#  'https://yugioh.fandom.com/wiki/Number_103:_Ragnazero',
#  'https://yugioh.fandom.com/wiki/Terra_the_Terrible',
#  'https://yugioh.fandom.com/wiki/Dinowrestler_Giga_Spinosavate',
#  'https://yugioh.fandom.com/wiki/Shared_Ride',
#  'https://yugioh.fandom.com/wiki/Flawless_Perfection_of_the_Tenyi',
#  'https://yugioh.fandom.com/wiki/D2_Shield',
#  'https://yugioh.fandom.com/wiki/Sadion,_the_Timelord',
#  'https://yugioh.fandom.com/wiki/Prank-Kids_Plan',
#  'https://yugioh.fandom.com/wiki/Etoile_Cyber',
#  'https://yugioh.fandom.com/wiki/Rescue_Ferret',
#  'https://yugioh.fandom.com/wiki/Flamvell_Magician',
#  'https://yugioh.fandom.com/wiki/Parasite_Paracide',
#  'https://yugioh.fandom.com/wiki/Gem-Merchant',
#  'https://yugioh.fandom.com/wiki/Dragon_Spirit_of_White',
#  'https://yugioh.fandom.com/wiki/Vylon_Element',
#  'https://yugioh.fandom.com/wiki/Sylvan_Snapdrassinagon',
#  'https://yugioh.fandom.com/wiki/Nidhogg,_Generaider_Boss_of_Ice',
#  'https://yugioh.fandom.com/wiki/Beautiful_Beast_Trainer',
#  'https://yugioh.fandom.com/wiki/Superheavy_Samurai_Transporter',
#  'https://yugioh.fandom.com/wiki/Orbital_Hydralander',
#  'https://yugioh.fandom.com/wiki/Spiritual_Water_Art_-_Aoi',
#  'https://yugioh.fandom.com/wiki/Rush_Recklessly',
#  'https://yugioh.fandom.com/wiki/Worm_Illidan',
#  'https://yugioh.fandom.com/wiki/Guardragon_Elpy',
#  'https://yugioh.fandom.com/wiki/Coach_Goblin',
#  'https://yugioh.fandom.com/wiki/Super_Roboyarou',
#  'https://yugioh.fandom.com/wiki/Arcana_Knight_Joker',
#  'https://yugioh.fandom.com/wiki/Grinder_Golem',
#  'https://yugioh.fandom.com/wiki/Gravekeeper%27s_Spiritualist',
#  'https://yugioh.fandom.com/wiki/Jirai_Gumo',
#  'https://yugioh.fandom.com/wiki/Ghost_Beef',
#  'https://yugioh.fandom.com/wiki/Caius_the_Mega_Monarch',
#  'https://yugioh.fandom.com/wiki/Lightserpent',
#  'https://yugioh.fandom.com/wiki/Cosmo_Brain',
#  'https://yugioh.fandom.com/wiki/Sentence_of_Doom',
#  'https://yugioh.fandom.com/wiki/Nightmare_Archfiends',
#  'https://yugioh.fandom.com/wiki/Doriado',
#  'https://yugioh.fandom.com/wiki/Astrograph_Sorcerer',
#  'https://yugioh.fandom.com/wiki/Ally_Mind',
#  'https://yugioh.fandom.com/wiki/Tricky_Spell_4',
#  'https://yugioh.fandom.com/wiki/Concentrating_Current',
#  'https://yugioh.fandom.com/wiki/Lunalight_Serenade_Dance',
#  'https://yugioh.fandom.com/wiki/Zero_Gravity',
#  'https://yugioh.fandom.com/wiki/Amulet_Dragon',
#  'https://yugioh.fandom.com/wiki/Serenade_the_Melodious_Diva',
#  'https://yugioh.fandom.com/wiki/Aromage_Bergamot',
#  'https://yugioh.fandom.com/wiki/Performapal_Celestial_Magician',
#  'https://yugioh.fandom.com/wiki/Swing_of_Memories',
#  'https://yugioh.fandom.com/wiki/Mimiclay',
#  'https://yugioh.fandom.com/wiki/Talisman_of_Spell_Sealing',
#  'https://yugioh.fandom.com/wiki/Hyper-Ancient_Shark_Megalodon',
#  'https://yugioh.fandom.com/wiki/Trading_Places',
#  'https://yugioh.fandom.com/wiki/Dragon_Revival_Rhapsody',
#  'https://yugioh.fandom.com/wiki/Meklord_Emperor_Wisel',
#  'https://yugioh.fandom.com/wiki/Penumbral_Soldier_Lady',
#  'https://yugioh.fandom.com/wiki/Trident_Warrior',
#  'https://yugioh.fandom.com/wiki/Power_of_the_Guardians',
#  'https://yugioh.fandom.com/wiki/Frost_Blast_of_the_Monarchs',
#  'https://yugioh.fandom.com/wiki/Assault_Wyvern',
#  'https://yugioh.fandom.com/wiki/R-Genex_Overseer',
#  'https://yugioh.fandom.com/wiki/Performapal_Handsamuraiger',
#  'https://yugioh.fandom.com/wiki/Red-Eyes_Black_Dragon',
#  'https://yugioh.fandom.com/wiki/Satellarknight_Capella',
#  'https://yugioh.fandom.com/wiki/Qliphort_Monolith',
#  'https://yugioh.fandom.com/wiki/Djinn_Disserere_of_Rituals',
#  'https://yugioh.fandom.com/wiki/Razor_Lizard',
#  'https://yugioh.fandom.com/wiki/Fusion_Weapon',
#  'https://yugioh.fandom.com/wiki/Star_Seraph_Scepter',
#  'https://yugioh.fandom.com/wiki/Queen%27s_Pawn',
#  'https://yugioh.fandom.com/wiki/Five-Headed_Dragon',
#  'https://yugioh.fandom.com/wiki/Wind-Up_Magician',
#  'https://yugioh.fandom.com/wiki/Light_and_Darkness_Dragon',
#  'https://yugioh.fandom.com/wiki/Yosenju_Tsujik',
#  'https://yugioh.fandom.com/wiki/Meklord_Emperor_Skiel',
#  'https://yugioh.fandom.com/wiki/Dark_Zebra',
#  'https://yugioh.fandom.com/wiki/Ninja_Grandmaster_Sasuke',
#  'https://yugioh.fandom.com/wiki/Graceful_Dice',
#  'https://yugioh.fandom.com/wiki/D/D/D_Abyss_King_Gilgamesh',
#  'https://yugioh.fandom.com/wiki/Steelswarm_Hercules',
#  'https://yugioh.fandom.com/wiki/Five-Headed_Link_Dragon',
#  'https://yugioh.fandom.com/wiki/Fire_Formation_-_Yoko',
#  'https://yugioh.fandom.com/wiki/Number_64:_Ronin_Raccoon_Sandayu',
#  'https://yugioh.fandom.com/wiki/Link_Burst',
#  'https://yugioh.fandom.com/wiki/Swords_at_Dawn',
#  'https://yugioh.fandom.com/wiki/Pulse_Mines',
#  'https://yugioh.fandom.com/wiki/Alien_Ammonite',
#  'https://yugioh.fandom.com/wiki/Ambulanceroid',
#  'https://yugioh.fandom.com/wiki/Mekk-Knight_Indigo_Eclipse',
#  'https://yugioh.fandom.com/wiki/Performapal_Gumgumouton',
#  'https://yugioh.fandom.com/wiki/Underworld_Fighter_Balmung',
#  'https://yugioh.fandom.com/wiki/Bi%27an,_Earth_of_the_Yang_Zing',
#  'https://yugioh.fandom.com/wiki/Pyramid_Turtle',
#  'https://yugioh.fandom.com/wiki/Give_and_Take',
#  'https://yugioh.fandom.com/wiki/Battlewasp_-_Azusa_the_Ghost_Bow',
#  'https://yugioh.fandom.com/wiki/Ignoble_Knight_of_Black_Laundsallyn',
#  'https://yugioh.fandom.com/wiki/Number_C39:_Utopia_Ray',
#  'https://yugioh.fandom.com/wiki/Neko_Mane_King',
#  'https://yugioh.fandom.com/wiki/Performapal_Sellshell_Crab',
#  'https://yugioh.fandom.com/wiki/Giant_Ballpark',
#  'https://yugioh.fandom.com/wiki/Spirit_Converter',
#  'https://yugioh.fandom.com/wiki/Anti-Aircraft_Flower',
#  'https://yugioh.fandom.com/wiki/Togex',
#  'https://yugioh.fandom.com/wiki/Ebon_Illusion_Magician',
#  'https://yugioh.fandom.com/wiki/Ushi_Oni',
#  'https://yugioh.fandom.com/wiki/Psychic_Reactor',
#  'https://yugioh.fandom.com/wiki/Performapal_Call',
#  'https://yugioh.fandom.com/wiki/Naturia_Landoise',
#  'https://yugioh.fandom.com/wiki/Marshmallon_Glasses',
#  'https://yugioh.fandom.com/wiki/Saryuja_Skull_Dread',
#  'https://yugioh.fandom.com/wiki/Kuriboh_Token',
#  'https://yugioh.fandom.com/wiki/Call_of_the_Grave',
#  'https://yugioh.fandom.com/wiki/Super_Defense_Robot_Elephan',
#  'https://yugioh.fandom.com/wiki/The_Lady_in_Wight',
#  'https://yugioh.fandom.com/wiki/Wattpheasant',
#  'https://yugioh.fandom.com/wiki/Grapple_Blocker',
#  'https://yugioh.fandom.com/wiki/Blazing_Hiita',
#  'https://yugioh.fandom.com/wiki/Dragon_Capture_Jar',
#  'https://yugioh.fandom.com/wiki/Appliancer_Kappa_Scale',
#  'https://yugioh.fandom.com/wiki/Sky_Scout',
#  'https://yugioh.fandom.com/wiki/Malefic_Tune',
#  'https://yugioh.fandom.com/wiki/Hazy_Flame_Griffin',
#  'https://yugioh.fandom.com/wiki/Performance_of_Sword',
#  'https://yugioh.fandom.com/wiki/Steelswarm_Mantis',
#  'https://yugioh.fandom.com/wiki/Vice_Berserker',
#  'https://yugioh.fandom.com/wiki/Amphibious_Swarmship_Amblowhale',
#  'https://yugioh.fandom.com/wiki/Wind-Up_Kitten',
#  'https://yugioh.fandom.com/wiki/The_Eye_of_Timaeus',
#  'https://yugioh.fandom.com/wiki/Yosenju_Sabu',
#  'https://yugioh.fandom.com/wiki/Darkness_Approaches',
#  'https://yugioh.fandom.com/wiki/Hinotama',
#  'https://yugioh.fandom.com/wiki/Spellbook_of_Secrets',
#  'https://yugioh.fandom.com/wiki/Ancient_Warriors_-_Ingenious_Zhuge_Kong',
#  'https://yugioh.fandom.com/wiki/Battle_Tuned',
#  'https://yugioh.fandom.com/wiki/Sonic_Warrior',
#  'https://yugioh.fandom.com/wiki/Dinomists_Howling',
#  'https://yugioh.fandom.com/wiki/Photon_Trident',
#  'https://yugioh.fandom.com/wiki/Cataclysmic_Scorching_Sunburner',
#  'https://yugioh.fandom.com/wiki/Paleozoic_Opabinia',
#  'https://yugioh.fandom.com/wiki/Double_Coston',
#  'https://yugioh.fandom.com/wiki/Super_Soldier_Rebirth',
#  'https://yugioh.fandom.com/wiki/Caius_the_Shadow_Monarch',
#  'https://yugioh.fandom.com/wiki/Crimson_Nova_the_Dark_Cubic_Lord',
#  'https://yugioh.fandom.com/wiki/Draco_Masters_of_the_Tenyi',
#  'https://yugioh.fandom.com/wiki/Weights_%26_Zenmaisures',
#  'https://yugioh.fandom.com/wiki/Trance_the_Magic_Swordsman',
#  'https://yugioh.fandom.com/wiki/Crystal_Master',
#  'https://yugioh.fandom.com/wiki/Super_Anti-Kaiju_War_Machine_Mecha-Dogoran',
#  'https://yugioh.fandom.com/wiki/Twilight_Ninja_Kagen',
#  'https://yugioh.fandom.com/wiki/Yormungarde',
#  'https://yugioh.fandom.com/wiki/Restoration_of_the_Monarchs',
#  'https://yugioh.fandom.com/wiki/Gouki_The_Solid_Ogre',
#  'https://yugioh.fandom.com/wiki/Palladium_Oracle_Mahad',
#  'https://yugioh.fandom.com/wiki/World_Legacy_Collapse',
#  'https://yugioh.fandom.com/wiki/Future_Samurai',
#  'https://yugioh.fandom.com/wiki/Neo_Super_Quantal_Mech_King_Blaster_Magna',
#  'https://yugioh.fandom.com/wiki/Tenmataitei',
#  'https://yugioh.fandom.com/wiki/Mad_Archfiend',
#  'https://yugioh.fandom.com/wiki/Armored_Bitron',
#  'https://yugioh.fandom.com/wiki/Appliancer_Electrilyrical_World',
#  'https://yugioh.fandom.com/wiki/Koa%27ki_Meiru_Initialize!',
#  'https://yugioh.fandom.com/wiki/Murmur_of_the_Forest',
#  'https://yugioh.fandom.com/wiki/Rage_of_the_Deep_Sea',
#  'https://yugioh.fandom.com/wiki/Vile_Germs',
#  'https://yugioh.fandom.com/wiki/The_Forgiving_Maiden',
#  'https://yugioh.fandom.com/wiki/Amazoness_Village',
#  'https://yugioh.fandom.com/wiki/Malefic_Stardust_Dragon',
#  'https://yugioh.fandom.com/wiki/Bound_Wand',
#  'https://yugioh.fandom.com/wiki/Majespecter_Storm',
#  'https://yugioh.fandom.com/wiki/Jain,_Twilightsworn_General',
#  'https://yugioh.fandom.com/wiki/Zenmaiday',
#  'https://yugioh.fandom.com/wiki/The_Second_Sarcophagus',
#  'https://yugioh.fandom.com/wiki/Knightmare_Incarnation_Idlee',
#  'https://yugioh.fandom.com/wiki/Sky_Striker_Maneuver_-_Vector_Blast',
#  'https://yugioh.fandom.com/wiki/Destruction_of_Destiny',
#  'https://yugioh.fandom.com/wiki/Legendary_Jujitsu_Master',
#  'https://yugioh.fandom.com/wiki/Psychic_Jumper',
#  'https://yugioh.fandom.com/wiki/Tenyi_Spirit_-_Ashuna',
#  'https://yugioh.fandom.com/wiki/Majesty_Maiden,_the_True_Dracocaster',
#  'https://yugioh.fandom.com/wiki/Saber_Shark',
#  'https://yugioh.fandom.com/wiki/Pendulum_Paradox',
#  'https://yugioh.fandom.com/wiki/Security_Dragon',
#  'https://yugioh.fandom.com/wiki/Indiora_Doom_Volt_the_Cubic_Emperor',
#  'https://yugioh.fandom.com/wiki/Makyura_the_Destructor',
#  'https://yugioh.fandom.com/wiki/Twin-Headed_Fire_Dragon',
#  'https://yugioh.fandom.com/wiki/Voltester',
#  'https://yugioh.fandom.com/wiki/Red-Eyes_Zombie_Dragon',
#  'https://yugioh.fandom.com/wiki/Flower_Cardian_Cherry_Blossom_with_Curtain',
#  'https://yugioh.fandom.com/wiki/Big_Jaws',
#  'https://yugioh.fandom.com/wiki/Abyssal_Designator',
#  'https://yugioh.fandom.com/wiki/Digital_Bug_Websolder',
#  'https://yugioh.fandom.com/wiki/Tribe-Infecting_Virus',
#  'https://yugioh.fandom.com/wiki/Extra_Buck',
#  'https://yugioh.fandom.com/wiki/D.D._Crazy_Beast',
#  'https://yugioh.fandom.com/wiki/Aurora_Wing',
#  'https://yugioh.fandom.com/wiki/Master_%26_Expert',
#  'https://yugioh.fandom.com/wiki/Guardian_of_the_Golden_Land',
#  'https://yugioh.fandom.com/wiki/Heroic_Challenger_-_Ambush_Soldier',
#  'https://yugioh.fandom.com/wiki/Garlandolf,_King_of_Destruction',
#  'https://yugioh.fandom.com/wiki/Constellar_Hyades',
#  'https://yugioh.fandom.com/wiki/Magical_Something',
#  'https://yugioh.fandom.com/wiki/Tyrant%27s_Throes',
#  'https://yugioh.fandom.com/wiki/Batteryman_Solar',
#  'https://yugioh.fandom.com/wiki/Performapal_Spikeagle',
#  'https://yugioh.fandom.com/wiki/Rank-Up-Magic_Raptor%27s_Force',
#  'https://yugioh.fandom.com/wiki/Nekroz_of_Brionac',
#  'https://yugioh.fandom.com/wiki/Lose_1_Turn',
#  'https://yugioh.fandom.com/wiki/Tatakawa_Knight',
#  'https://yugioh.fandom.com/wiki/Sea_Lord%27s_Amulet',
#  'https://yugioh.fandom.com/wiki/Winged_Kuriboh',
#  'https://yugioh.fandom.com/wiki/Fire_Formation_-_Gyokkou',
#  'https://yugioh.fandom.com/wiki/Prediction_Princess_Coinorma',
#  'https://yugioh.fandom.com/wiki/Giant_Trap_Hole',
#  'https://yugioh.fandom.com/wiki/Stegocyber',
#  'https://yugioh.fandom.com/wiki/Time_Pendulumgraph',
#  'https://yugioh.fandom.com/wiki/Evolsaur_Pelta',
#  'https://yugioh.fandom.com/wiki/Gwenhwyfar,_Queen_of_Noble_Arms',
#  'https://yugioh.fandom.com/wiki/Cyberdark_Impact!',
#  'https://yugioh.fandom.com/wiki/Imairuka',
#  'https://yugioh.fandom.com/wiki/Sauropod_Brachion',
#  'https://yugioh.fandom.com/wiki/Ectoplasmic_Fortification!',
#  'https://yugioh.fandom.com/wiki/Volcanic_Doomfire',
#  'https://yugioh.fandom.com/wiki/The_Melting_Red_Shadow',
#  'https://yugioh.fandom.com/wiki/Heraldic_Beast_Leo',
#  'https://yugioh.fandom.com/wiki/Oracle_of_Zefra',
#  'https://yugioh.fandom.com/wiki/Adamancipator_Signs',
#  'https://yugioh.fandom.com/wiki/The_Golden_Apples',
#  'https://yugioh.fandom.com/wiki/Garoth,_Lightsworn_Warrior',
#  'https://yugioh.fandom.com/wiki/Slash_Draw',
#  'https://yugioh.fandom.com/wiki/Trakodon',
#  'https://yugioh.fandom.com/wiki/Sky_Cavalry_Centaurea',
#  'https://yugioh.fandom.com/wiki/Boulder_Tortoise',
#  'https://yugioh.fandom.com/wiki/Pulling_the_Rug',
#  'https://yugioh.fandom.com/wiki/Ground_Spider',
#  'https://yugioh.fandom.com/wiki/Gaap_the_Divine_Soldier',
#  'https://yugioh.fandom.com/wiki/Legendary_Sword',
#  'https://yugioh.fandom.com/wiki/Temtempo_the_Percussion_Djinn',
#  'https://yugioh.fandom.com/wiki/Ninjitsu_Art_of_Transformation',
#  'https://yugioh.fandom.com/wiki/Magical_King_Moonstar',
#  'https://yugioh.fandom.com/wiki/Performapal_Uni',
#  'https://yugioh.fandom.com/wiki/Reese_the_Ice_Mistress',
#  'https://yugioh.fandom.com/wiki/Flower_Cardian_Boardefly',
#  'https://yugioh.fandom.com/wiki/Ally_of_Justice_Field_Marshal',
#  'https://yugioh.fandom.com/wiki/Heraldic_Beast_Twin-Headed_Eagle',
#  'https://yugioh.fandom.com/wiki/Abyss_Script_-_Rise_of_the_Abyss_King',
#  'https://yugioh.fandom.com/wiki/Gazer_Shark',
#  'https://yugioh.fandom.com/wiki/Cyberse_Magician',
#  'https://yugioh.fandom.com/wiki/Inspector_Boarder',
#  'https://yugioh.fandom.com/wiki/Nemeses_Corridor',
#  'https://yugioh.fandom.com/wiki/Solomon%27s_Lawbook',
#  'https://yugioh.fandom.com/wiki/Butterflyoke',
#  'https://yugioh.fandom.com/wiki/Wow_Warrior',
#  'https://yugioh.fandom.com/wiki/Chain_Ignition',
#  'https://yugioh.fandom.com/wiki/Gadget_Soldier',
#  'https://yugioh.fandom.com/wiki/Ostinato',
#  'https://yugioh.fandom.com/wiki/Gladiator_Beast%27s_Respite',
#  'https://yugioh.fandom.com/wiki/Nimble_Manta',
#  'https://yugioh.fandom.com/wiki/Rampaging_Smashtank_Rhynosaber',
#  'https://yugioh.fandom.com/wiki/Doriado%27s_Blessing',
#  'https://yugioh.fandom.com/wiki/Goyo_Chaser',
#  'https://yugioh.fandom.com/wiki/Jurrac_Monoloph',
#  'https://yugioh.fandom.com/wiki/Absolute_End',
#  'https://yugioh.fandom.com/wiki/Non_Aggression_Area',
#  'https://yugioh.fandom.com/wiki/Zoma_the_Spirit',
#  'https://yugioh.fandom.com/wiki/Inzektor_Centipede',
#  'https://yugioh.fandom.com/wiki/Madolche_Waltz',
#  'https://yugioh.fandom.com/wiki/Tin_Archduke',
#  'https://yugioh.fandom.com/wiki/Fossil_Dig',
#  'https://yugioh.fandom.com/wiki/Griggle',
#  'https://yugioh.fandom.com/wiki/World_Legacy_Awakens',
#  'https://yugioh.fandom.com/wiki/Moulinglacia_the_Elemental_Lord',
#  'https://yugioh.fandom.com/wiki/Snowdust_Giant',
#  'https://yugioh.fandom.com/wiki/Tiger_Axe',
#  'https://yugioh.fandom.com/wiki/Rainbow_Gravity',
#  'https://yugioh.fandom.com/wiki/Disk_Magician',
#  'https://yugioh.fandom.com/wiki/Soundproofed',
#  'https://yugioh.fandom.com/wiki/Kagetokage',
#  'https://yugioh.fandom.com/wiki/Phoenix_Gearfried',
#  'https://yugioh.fandom.com/wiki/Carrierroid',
#  'https://yugioh.fandom.com/wiki/Wings_of_Wicked_Flame',
#  'https://yugioh.fandom.com/wiki/Key_Mouse',
#  ...]

# %%
len(card_url_list)
# Out:
# 10176

# %%
next(card_url_iterable)
# Out:
# ['https://yugioh.fandom.com/wiki/Kamionwizard',
#  'https://yugioh.fandom.com/wiki/Stone_Armadiller',
#  'https://yugioh.fandom.com/wiki/Machine_Conversion_Factory',
#  'https://yugioh.fandom.com/wiki/Hard_Armor',
#  'https://yugioh.fandom.com/wiki/The_Bewitching_Phantom_Thief',
#  'https://yugioh.fandom.com/wiki/Curse_of_Dragon',
#  'https://yugioh.fandom.com/wiki/Blue-Eyed_Silver_Zombie',
#  'https://yugioh.fandom.com/wiki/De-Spell',
#  'https://yugioh.fandom.com/wiki/Tyhone',
#  'https://yugioh.fandom.com/wiki/Zombie_Warrior',
#  'https://yugioh.fandom.com/wiki/Dragoness_the_Wicked_Knight',
#  'https://yugioh.fandom.com/wiki/Final_Flame',
#  'https://yugioh.fandom.com/wiki/M-Warrior_1',
#  'https://yugioh.fandom.com/wiki/Dorover',
#  'https://yugioh.fandom.com/wiki/Terra_the_Terrible',
#  'https://yugioh.fandom.com/wiki/Mavelus',
#  'https://yugioh.fandom.com/wiki/Karbonala_Warrior',
#  'https://yugioh.fandom.com/wiki/Solitude',
#  'https://yugioh.fandom.com/wiki/Kumootoko',
#  'https://yugioh.fandom.com/wiki/Claw_Reacher',
#  'https://yugioh.fandom.com/wiki/Goblin%27s_Secret_Remedy',
#  'https://yugioh.fandom.com/wiki/Armaill',
#  'https://yugioh.fandom.com/wiki/Spirit_of_the_Harp',
#  'https://yugioh.fandom.com/wiki/Man_Eater',
#  'https://yugioh.fandom.com/wiki/Holograh',
#  'https://yugioh.fandom.com/wiki/One-Eyed_Shield_Dragon',
#  'https://yugioh.fandom.com/wiki/Wood_Remains',
#  'https://yugioh.fandom.com/wiki/Enchanting_Mermaid',
#  'https://yugioh.fandom.com/wiki/M-Warrior_2',
#  'https://yugioh.fandom.com/wiki/Raise_Body_Heat',
#  'https://yugioh.fandom.com/wiki/Vile_Germs',
#  'https://yugioh.fandom.com/wiki/Meda_Bat',
#  'https://yugioh.fandom.com/wiki/Mystical_Elf',
#  'https://yugioh.fandom.com/wiki/Uraby',
#  'https://yugioh.fandom.com/wiki/Larvas',
#  'https://yugioh.fandom.com/wiki/Monster_Reborn',
#  'https://yugioh.fandom.com/wiki/Dark_Energy',
#  'https://yugioh.fandom.com/wiki/Laser_Cannon_Armor',
#  'https://yugioh.fandom.com/wiki/Supporter_in_the_Shadows',
#  'https://yugioh.fandom.com/wiki/Swords_of_Revealing_Light']

# %%
set(card_url_iterable)
# Out:
# set()

# %%
len(card_url_iterable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-85fa5c37044e> in <module>
# ----> 1 len(card_url_iterable)
#
# TypeError: object of type 'generator' has no len()
