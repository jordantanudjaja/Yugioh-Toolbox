# %%
import os

# %%
os.chdir('..')

# %%
from yugioh import ygfandom as ygf, banlist, tcgplayer as tcg
import time
import concurrent.futures

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jorda\\OneDrive\\Desktop\\Personal Projects\\Yugioh Web Scraping Toolbox'

# %%
help(ygf)
# Out:
# Help on module yugioh.yugioh.ygfandom in yugioh.yugioh:
#
# NAME
#     yugioh.yugioh.ygfandom - Created on Thu Jul 30 18:06:24 2020
#
# DESCRIPTION
#     Author: Jordan Tanudjaja
#
#     Python module for anything related to yugioh in (https://yugioh.fandom.com)
#     and the 'Yugioh Card Database.csv' file that was initialized on July 29 2020 in this directory.
#
# CLASSES
#     builtins.object
#         DbHandler
#         YgScraper
#
#     class DbHandler(builtins.object)
#      |  DbHandler(database_filepath='Data/Yugioh Card Database.csv')
#      |
#      |  Class for handling and manipulating the yugioh card database
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, database_filepath='Data/Yugioh Card Database.csv')
#      |      Parameters:
#      |      -----------
#      |      database_filepath: str
#      |          Default value: 'Data/Yugioh Card Database.csv'
#      |          The value has to be in a CSV format, and the default path leads to a
# ...

# %%
duelist = ygf.DbHandler()

# %%
df = duelist.get_card_database()
df
# Out:
#                                  Card Name  \
# 0                Divine Grace - Northwemko
# 1                            Double Summon
# 2                        Zoodiac Gathering
# 3           The Legendary Exodia Incarnate
# 4                          Dark Designator
# ...                                    ...
# 10387                      Frightfur March
# 10388                          Shapesister
# 10389                      Gotterdammerung
# 10390                     Summon Sorceress
# 10391  Heroic Challenger - Thousand Blades
#
#                                                Card Type Spell/Trap Property  \
# 0                                                Monster                 N/A
# 1                                                  Spell              Normal
# 2                                                   Trap          Continuous
# 3                                                Monster                 N/A
# ...

# %%
duelist.locate_card('https://yugioh.fandom.com/wiki/Heroic_Challenger_-_Thousand_Blades')
# Out:
# Heroic Challenger - Thousand Blades is already in the Yugioh database and it is located at index: 298
# 298

# %%
df = df[:-1]

# %%
duelist.set_card_database(df)
duelist.get_card_database()
# Out:
#                             Card Name Card Type Spell/Trap Property Attribute  \
# 0           Divine Grace - Northwemko   Monster                 N/A     LIGHT
# 1                       Double Summon     Spell              Normal       N/A
# 2                   Zoodiac Gathering      Trap          Continuous       N/A
# 3      The Legendary Exodia Incarnate   Monster                 N/A      DARK
# 4                     Dark Designator     Spell              Normal       N/A
# ...                               ...       ...                 ...       ...
# 10386                       Iron Hans   Monster                 N/A     EARTH
# 10387                 Frightfur March      Trap             Counter       N/A
# 10388                     Shapesister      Trap          Continuous       N/A
# 10389                 Gotterdammerung     Spell              Normal       N/A
# 10390                Summon Sorceress   Monster                 N/A      DARK
#
# ...

# %%
duelist.save_card_database()
# Out:
# Save successful

# %%
duelist_backup = ygf.DbHandler(database_filepath = 'yugioh/Data/Yugioh Card Database (Backup).csv')

# %%
duelist_backup.get_card_database()
# Out:
#                             Card Name Card Type Spell/Trap Property Attribute  \
# 0           Divine Grace - Northwemko   Monster                 N/A     LIGHT
# 1                       Double Summon     Spell              Normal       N/A
# 2                   Zoodiac Gathering      Trap          Continuous       N/A
# 3      The Legendary Exodia Incarnate   Monster                 N/A      DARK
# 4                     Dark Designator     Spell              Normal       N/A
# ...                               ...       ...                 ...       ...
# 10386                       Iron Hans   Monster                 N/A     EARTH
# 10387                 Frightfur March      Trap             Counter       N/A
# 10388                     Shapesister      Trap          Continuous       N/A
# 10389                 Gotterdammerung     Spell              Normal       N/A
# 10390                Summon Sorceress   Monster                 N/A      DARK
#
# ...
